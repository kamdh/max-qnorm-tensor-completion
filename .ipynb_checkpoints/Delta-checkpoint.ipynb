# %%
#import jax.numpy as np
#from jax import pmap
import numpy as np
from maxnorm.maxnorm_completion import *
from maxnorm.tenalg import *
from maxnorm.graphs import *
import sparse
from itertools import product
import networkx as nx

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %load_ext autoreload

# %%
# create random, low-rank tensor
t = 5
n = 30
r = 3
max_iterations = 100
epsilons = np.logspace(-4, 0, 5)
epsilons = np.concatenate((np.array(0), epsilons), axis = None)
#delta = 0.1
const = 24
sigma = 0.005
ndata =  const * r * t * n * np.log10(n)
U = kr_random(n, t, r, rvs='unif')
U = kr_rescale(U, np.sqrt(n**t), 'hs')
norm_true = np.sqrt(kr_dot(U, U) / n**t)
#U = [np.random.randn(n, r) for i in range(t)]
print("n data: %.2e" % ndata)
print("n data ** t/2: %.2e" % int(const * r * n**(t/2) * np.log10(n)))
print("true norm: %.2e" % norm_true)
# Out:
# n data: 1.60e+04
# n data ** t/2: 5.24e+05
# true norm: 1.00e+00

# %%
qnorm_true = max_qnorm_ub(U)
print(qnorm_true)
print(r**(t/2))
# Out:
# 48.794369382213716
# 15.588457268119896

# %%
expander = nx.random_regular_graph(6, n)
#expander = nx.chordal_cycle_graph(n)
observation_mask = obs_mask_expander(expander, t)
#observation_mask = obs_mask_iid(tuple([n for i in range(t)]), ndata * n**(-t))

# %%
from run_sweep_iid import generate_data


data = generate_data(observation_mask, U, sigma)
clean_data_rmse = np.sqrt(loss(U, data) / data.nnz)
print(data.nnz)
print(ndata)
print(n**t)
print("%0.1e%%" % (float(data.nnz) / n**t * 100))
# Out:
# 38880
# 15952.909550972354
# 24300000
# 1.6e-01%

# %%
def print_factor_norms(U):
    print("fro:   " + str([np.linalg.norm(Ui,'fro')**2 for Ui in U]))
    print("2-inf: " + str([np.max(np.linalg.norm(Ui, axis=1)) for Ui in U]))

print_factor_norms(kr_balance_factors(U))
# Out:
# fro:   [71.73536184266835, 71.73536184266835, 71.73536184266835, 71.73536184266835, 71.73536184266835]
# 2-inf: [2.083180102742442, 2.133106616500008, 2.4386127778012443, 2.194578434132449, 2.051846599917727]

# %%
delta = 1.5 * sigma
#np.sqrt(np.sum((data.data - clean_data)**2)) * 2 / np.sqrt(data.nnz) * 1.5

print("rms of data:        %f" % clean_data_rmse)
print("delta parameter:    %f" % delta)
print("rmse of U true:     %f" % np.sqrt(loss(U, data) / data.nnz))
# Out:
# rms of data:        0.004984
# delta parameter:    0.007500
# rmse of U true:     0.004984

# %%
#Uinit = kr_rescale(Unew1, np.sqrt(np.product(data.shape) * data.sum() ** 2 / data.nnz), 'hs')
# Uinit = kr_balance_factors(Unew1)

# %%
# %autoreload
Unew2_list = []
cost_arr_list = []
deltas = np.logspace(-6, -3, 4)
eps = 1e-4
print(deltas)
print(sigma)
# sigma = deltas[-1] * np.sqrt(data.nnz)
for delta in deltas:
    print("delta = ", delta)
    Unew2, cost_arr = tensor_completion_maxnorm(data, 4 * r**t, delta, epsilon=eps,
                                                #sgd=True, sgd_batch_size=2000,
                                                #U0 = kr_balance_factors(Unew1),
                                                init='svdrand',
                                                kappa=100, beta=1, 
                                                tol=1e-10, inner_tol=1e-12, max_iter=300, inner_max_iter=10, 
                                                verbosity=1, inner_line_iter=40,
                                                rebalance=True)
    Unew2_list.append(Unew2)
    cost_arr_list.append(cost_arr)
# Out:
# [1.e-06 1.e-05 1.e-04 1.e-03]
# 0.005
# delta =  1e-06
# Initial cost: 1.832e+06
# Initial qnorm_ub: 9.315e+03
# || r || = 9.682e-01, delta = 5.072e-09
#
# =============================
# Iteration 0 complete
#
#
# scaled || r || = 4.665e-01, delta = 5.072e-09
# Max-qnorm upper bound: 1.314e+05
# Cost function:         5.545e+05
#
# =============================
#
#
# =============================
# Iteration 1 complete
#
#
# scaled || r || = 2.229e-01, delta = 5.072e-09
# Max-qnorm upper bound: 1.067e+05
# Cost function:         2.033e+05
#
# =============================
#
#
# =============================
# Iteration 2 complete
#
#
# scaled || r || = 1.521e-01, delta = 5.072e-09
# Max-qnorm upper bound: 9.094e+04
# Cost function:         1.360e+05
#
# =============================
#
#
# =============================
# Iteration 3 complete
#
#
# scaled || r || = 1.212e-01, delta = 5.072e-09
# Max-qnorm upper bound: 8.021e+04
# Cost function:         1.088e+05
#
# =============================
#
#
# =============================
# Iteration 4 complete
#
#
# scaled || r || = 1.015e-01, delta = 5.072e-09
# Max-qnorm upper bound: 7.148e+04
# Cost function:         9.158e+04
#
# =============================
#
#
# =============================
# Iteration 5 complete
#
#
# scaled || r || = 8.734e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.438e+04
# Cost function:         7.927e+04
#
# =============================
#
#
# =============================
# Iteration 6 complete
#
#
# scaled || r || = 7.746e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.878e+04
# Cost function:         7.050e+04
#
# =============================
#
#
# =============================
# Iteration 7 complete
#
#
# scaled || r || = 6.973e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.397e+04
# Cost function:         6.348e+04
#
# =============================
#
#
# =============================
# Iteration 8 complete
#
#
# scaled || r || = 6.395e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.011e+04
# Cost function:         5.812e+04
#
# =============================
#
#
# =============================
# Iteration 9 complete
#
#
# scaled || r || = 5.886e-02, delta = 5.072e-09
# Max-qnorm upper bound: 4.658e+04
# Cost function:         5.337e+04
#
# =============================
#
#
# =============================
# Iteration 10 complete
#
#
# scaled || r || = 5.484e-02, delta = 5.072e-09
# Max-qnorm upper bound: 4.364e+04
# Cost function:         4.954e+04
#
# =============================
#
#
# =============================
# Iteration 11 complete
#
#
# scaled || r || = 5.121e-02, delta = 5.072e-09
# Max-qnorm upper bound: 4.089e+04
# Cost function:         4.604e+04
#
# =============================
#
#
# =============================
# Iteration 12 complete
#
#
# scaled || r || = 4.822e-02, delta = 5.072e-09
# Max-qnorm upper bound: 3.855e+04
# Cost function:         4.312e+04
#
# =============================
#
#
# =============================
# Iteration 13 complete
#
#
# scaled || r || = 4.567e-02, delta = 5.072e-09
# Max-qnorm upper bound: 3.648e+04
# Cost function:         4.058e+04
#
# =============================
#
#
# =============================
# Iteration 14 complete
#
#
# scaled || r || = 4.340e-02, delta = 5.072e-09
# Max-qnorm upper bound: 3.454e+04
# Cost function:         3.825e+04
#
# =============================
#
#
# =============================
# Iteration 15 complete
#
#
# scaled || r || = 4.135e-02, delta = 5.072e-09
# Max-qnorm upper bound: 3.276e+04
# Cost function:         3.613e+04
#
# =============================
#
#
# =============================
# Iteration 16 complete
#
#
# scaled || r || = 3.950e-02, delta = 5.072e-09
# Max-qnorm upper bound: 3.118e+04
# Cost function:         3.426e+04
#
# =============================
#
#
# =============================
# Iteration 17 complete
#
#
# scaled || r || = 3.786e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.974e+04
# Cost function:         3.257e+04
#
# =============================
#
#
# =============================
# Iteration 18 complete
#
#
# scaled || r || = 3.635e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.840e+04
# Cost function:         3.101e+04
#
# =============================
#
#
# =============================
# Iteration 19 complete
#
#
# scaled || r || = 3.499e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.717e+04
# Cost function:         2.959e+04
#
# =============================
#
#
# =============================
# Iteration 20 complete
#
#
# scaled || r || = 3.374e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.603e+04
# Cost function:         2.829e+04
#
# =============================
#
#
# =============================
# Iteration 21 complete
#
#
# scaled || r || = 3.260e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.498e+04
# Cost function:         2.709e+04
#
# =============================
#
#
# =============================
# Iteration 22 complete
#
#
# scaled || r || = 3.154e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.403e+04
# Cost function:         2.601e+04
#
# =============================
#
#
# =============================
# Iteration 23 complete
#
#
# scaled || r || = 3.056e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.315e+04
# Cost function:         2.500e+04
#
# =============================
#
#
# =============================
# Iteration 24 complete
#
#
# scaled || r || = 2.964e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.231e+04
# Cost function:         2.406e+04
#
# =============================
#
#
# =============================
# Iteration 25 complete
#
#
# scaled || r || = 2.878e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.153e+04
# Cost function:         2.318e+04
#
# =============================
#
#
# =============================
# Iteration 26 complete
#
#
# scaled || r || = 2.794e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.082e+04
# Cost function:         2.238e+04
#
# =============================
#
#
# =============================
# Iteration 27 complete
#
#
# scaled || r || = 2.715e-02, delta = 5.072e-09
# Max-qnorm upper bound: 2.014e+04
# Cost function:         2.161e+04
#
# =============================
#
#
# =============================
# Iteration 28 complete
#
#
# scaled || r || = 2.641e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.952e+04
# Cost function:         2.091e+04
#
# =============================
#
#
# =============================
# Iteration 29 complete
#
#
# scaled || r || = 2.574e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.891e+04
# Cost function:         2.023e+04
#
# =============================
#
#
# =============================
# Iteration 30 complete
#
#
# scaled || r || = 2.507e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.835e+04
# Cost function:         1.961e+04
#
# =============================
#
#
# =============================
# Iteration 31 complete
#
#
# scaled || r || = 2.448e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.784e+04
# Cost function:         1.905e+04
#
# =============================
#
#
# =============================
# Iteration 32 complete
#
#
# scaled || r || = 2.389e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.732e+04
# Cost function:         1.847e+04
#
# =============================
#
#
# =============================
# Iteration 33 complete
#
#
# scaled || r || = 2.331e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.685e+04
# Cost function:         1.794e+04
#
# =============================
#
#
# =============================
# Iteration 34 complete
#
#
# scaled || r || = 2.275e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.641e+04
# Cost function:         1.746e+04
#
# =============================
#
#
# =============================
# Iteration 35 complete
#
#
# scaled || r || = 2.221e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.598e+04
# Cost function:         1.698e+04
#
# =============================
#
#
# =============================
# Iteration 36 complete
#
#
# scaled || r || = 2.175e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.557e+04
# Cost function:         1.653e+04
#
# =============================
#
#
# =============================
# Iteration 37 complete
#
#
# scaled || r || = 2.124e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.521e+04
# Cost function:         1.612e+04
#
# =============================
#
#
# =============================
# Iteration 38 complete
#
#
# scaled || r || = 2.079e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.482e+04
# Cost function:         1.570e+04
#
# =============================
#
#
# =============================
# Iteration 39 complete
#
#
# scaled || r || = 2.035e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.449e+04
# Cost function:         1.533e+04
#
# =============================
#
#
# =============================
# Iteration 40 complete
#
#
# scaled || r || = 1.994e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.416e+04
# Cost function:         1.497e+04
#
# =============================
# =============================
# Iteration 41 complete
#
#
# scaled || r || = 1.955e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.384e+04
# Cost function:         1.461e+04
#
# =============================
#
#
# =============================
# Iteration 42 complete
#
#
# scaled || r || = 1.913e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.355e+04
# Cost function:         1.430e+04
#
# =============================
#
#
# =============================
# Iteration 43 complete
#
#
# scaled || r || = 1.876e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.326e+04
# Cost function:         1.398e+04
#
# =============================
#
#
# =============================
# Iteration 44 complete
#
#
# scaled || r || = 1.841e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.299e+04
# Cost function:         1.368e+04
#
# =============================
#
#
# =============================
# Iteration 45 complete
#
#
# scaled || r || = 1.807e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.272e+04
# Cost function:         1.339e+04
#
# =============================
#
#
# =============================
# Iteration 46 complete
#
#
# scaled || r || = 1.775e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.248e+04
# Cost function:         1.312e+04
#
# =============================
#
#
# =============================
# Iteration 47 complete
#
#
# scaled || r || = 1.745e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.225e+04
# Cost function:         1.288e+04
#
# =============================
#
#
# =============================
# Iteration 48 complete
#
#
# scaled || r || = 1.717e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.203e+04
# Cost function:         1.263e+04
#
# =============================
#
#
# =============================
# Iteration 49 complete
#
#
# scaled || r || = 1.691e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.182e+04
# Cost function:         1.241e+04
#
# =============================
#
#
# =============================
# Iteration 50 complete
#
#
# scaled || r || = 1.665e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.161e+04
# Cost function:         1.219e+04
#
# =============================
#
#
# =============================
# Iteration 51 complete
#
#
# scaled || r || = 1.641e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.141e+04
# Cost function:         1.197e+04
#
# =============================
#
#
# =============================
# Iteration 52 complete
#
#
# scaled || r || = 1.618e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.123e+04
# Cost function:         1.177e+04
#
# =============================
#
#
# =============================
# Iteration 53 complete
#
#
# scaled || r || = 1.595e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.105e+04
# Cost function:         1.157e+04
#
# =============================
#
#
# =============================
# Iteration 54 complete
#
#
# scaled || r || = 1.573e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.087e+04
# Cost function:         1.138e+04
#
# =============================
#
#
# =============================
# Iteration 55 complete
#
#
# scaled || r || = 1.553e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.070e+04
# Cost function:         1.120e+04
#
# =============================
#
#
# =============================
# Iteration 56 complete
#
#
# scaled || r || = 1.533e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.053e+04
# Cost function:         1.102e+04
#
# =============================
#
#
# =============================
# Iteration 57 complete
#
#
# scaled || r || = 1.514e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.038e+04
# Cost function:         1.086e+04
#
# =============================
#
#
# =============================
# Iteration 58 complete
#
#
# scaled || r || = 1.497e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.025e+04
# Cost function:         1.071e+04
#
# =============================
#
#
# =============================
# Iteration 59 complete
#
#
# scaled || r || = 1.480e-02, delta = 5.072e-09
# Max-qnorm upper bound: 1.010e+04
# Cost function:         1.056e+04
#
# =============================
#
#
# =============================
# Iteration 60 complete
#
#
# scaled || r || = 1.464e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.955e+03
# Cost function:         1.040e+04
#
# =============================
#
#
# =============================
# Iteration 61 complete
#
#
# scaled || r || = 1.449e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.818e+03
# Cost function:         1.026e+04
#
# =============================
#
#
# =============================
# Iteration 62 complete
#
#
# scaled || r || = 1.434e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.683e+03
# Cost function:         1.011e+04
#
# =============================
#
#
# =============================
# Iteration 63 complete
#
#
# scaled || r || = 1.419e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.557e+03
# Cost function:         9.981e+03
#
# =============================
#
#
# =============================
# Iteration 64 complete
#
#
# scaled || r || = 1.405e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.429e+03
# Cost function:         9.845e+03
#
# =============================
#
#
# =============================
# Iteration 65 complete
#
#
# scaled || r || = 1.391e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.307e+03
# Cost function:         9.715e+03
#
# =============================
#
#
# =============================
# Iteration 66 complete
#
#
# scaled || r || = 1.378e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.185e+03
# Cost function:         9.586e+03
#
# =============================
#
#
# =============================
# Iteration 67 complete
#
#
# scaled || r || = 1.365e-02, delta = 5.072e-09
# Max-qnorm upper bound: 9.071e+03
# Cost function:         9.464e+03
#
# =============================
#
#
# =============================
# Iteration 68 complete
#
#
# scaled || r || = 1.352e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.958e+03
# Cost function:         9.345e+03
#
# =============================
#
#
# =============================
# Iteration 69 complete
#
#
# scaled || r || = 1.340e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.845e+03
# Cost function:         9.226e+03
#
# =============================
#
#
# =============================
# Iteration 70 complete
#
#
# scaled || r || = 1.328e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.737e+03
# Cost function:         9.111e+03
#
# =============================
#
#
# =============================
# Iteration 71 complete
#
#
# scaled || r || = 1.317e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.633e+03
# Cost function:         9.001e+03
#
# =============================
#
#
# =============================
# Iteration 72 complete
#
#
# scaled || r || = 1.306e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.529e+03
# Cost function:         8.891e+03
#
# =============================
#
#
# =============================
# Iteration 73 complete
#
#
# scaled || r || = 1.295e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.428e+03
# Cost function:         8.785e+03
#
# =============================
#
#
# =============================
# Iteration 74 complete
#
#
# scaled || r || = 1.285e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.332e+03
# Cost function:         8.684e+03
#
# =============================
#
#
# =============================
# Iteration 75 complete
#
#
# scaled || r || = 1.275e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.239e+03
# Cost function:         8.586e+03
#
# =============================
#
#
# =============================
# Iteration 76 complete
#
#
# scaled || r || = 1.265e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.144e+03
# Cost function:         8.486e+03
#
# =============================
#
#
# =============================
# Iteration 77 complete
#
#
# scaled || r || = 1.255e-02, delta = 5.072e-09
# Max-qnorm upper bound: 8.055e+03
# Cost function:         8.392e+03
#
# =============================
#
#
# =============================
# Iteration 78 complete
#
#
# scaled || r || = 1.246e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.971e+03
# Cost function:         8.303e+03
#
# =============================
#
#
# =============================
# Iteration 79 complete
#
#
# scaled || r || = 1.237e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.885e+03
# Cost function:         8.213e+03
#
# =============================
#
#
# =============================
# Iteration 80 complete
#
#
# scaled || r || = 1.229e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.802e+03
# Cost function:         8.126e+03
#
# =============================
#
#
# =============================
# Iteration 81 complete
#
#
# scaled || r || = 1.220e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.721e+03
# Cost function:         8.041e+03
#
# =============================
#
#
# =============================
# Iteration 82 complete
#
#
# scaled || r || = 1.213e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.642e+03
# Cost function:         7.958e+03
#
# =============================
# =============================
# Iteration 83 complete
#
#
# scaled || r || = 1.205e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.565e+03
# Cost function:         7.878e+03
#
# =============================
#
#
# =============================
# Iteration 84 complete
#
#
# scaled || r || = 1.196e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.489e+03
# Cost function:         7.797e+03
#
# =============================
#
#
# =============================
# Iteration 85 complete
#
#
# scaled || r || = 1.188e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.418e+03
# Cost function:         7.722e+03
#
# =============================
#
#
# =============================
# Iteration 86 complete
#
#
# scaled || r || = 1.181e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.344e+03
# Cost function:         7.645e+03
#
# =============================
#
#
# =============================
# Iteration 87 complete
#
#
# scaled || r || = 1.173e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.275e+03
# Cost function:         7.572e+03
#
# =============================
#
#
# =============================
# Iteration 88 complete
#
#
# scaled || r || = 1.166e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.204e+03
# Cost function:         7.498e+03
#
# =============================
#
#
# =============================
# Iteration 89 complete
#
#
# scaled || r || = 1.159e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.141e+03
# Cost function:         7.432e+03
#
# =============================
#
#
# =============================
# Iteration 90 complete
#
#
# scaled || r || = 1.152e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.073e+03
# Cost function:         7.360e+03
#
# =============================
#
#
# =============================
# Iteration 91 complete
#
#
# scaled || r || = 1.146e-02, delta = 5.072e-09
# Max-qnorm upper bound: 7.009e+03
# Cost function:         7.293e+03
#
# =============================
#
#
# =============================
# Iteration 92 complete
#
#
# scaled || r || = 1.139e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.945e+03
# Cost function:         7.226e+03
#
# =============================
#
#
# =============================
# Iteration 93 complete
#
#
# scaled || r || = 1.133e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.882e+03
# Cost function:         7.161e+03
#
# =============================
#
#
# =============================
# Iteration 94 complete
#
#
# scaled || r || = 1.126e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.822e+03
# Cost function:         7.097e+03
#
# =============================
#
#
# =============================
# Iteration 95 complete
#
#
# scaled || r || = 1.120e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.762e+03
# Cost function:         7.035e+03
#
# =============================
#
#
# =============================
# Iteration 96 complete
#
#
# scaled || r || = 1.115e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.705e+03
# Cost function:         6.976e+03
#
# =============================
#
#
# =============================
# Iteration 97 complete
#
#
# scaled || r || = 1.109e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.645e+03
# Cost function:         6.913e+03
#
# =============================
#
#
# =============================
# Iteration 98 complete
#
#
# scaled || r || = 1.103e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.587e+03
# Cost function:         6.852e+03
#
# =============================
#
#
# =============================
# Iteration 99 complete
#
#
# scaled || r || = 1.097e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.532e+03
# Cost function:         6.794e+03
#
# =============================
#
#
# =============================
# Iteration 100 complete
#
#
# scaled || r || = 1.092e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.477e+03
# Cost function:         6.737e+03
#
# =============================
#
#
# =============================
# Iteration 101 complete
#
#
# scaled || r || = 1.086e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.423e+03
# Cost function:         6.681e+03
#
# =============================
#
#
# =============================
# Iteration 102 complete
#
#
# scaled || r || = 1.081e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.370e+03
# Cost function:         6.626e+03
#
# =============================
#
#
# =============================
# Iteration 103 complete
#
#
# scaled || r || = 1.075e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.318e+03
# Cost function:         6.571e+03
#
# =============================
#
#
# =============================
# Iteration 104 complete
#
#
# scaled || r || = 1.070e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.266e+03
# Cost function:         6.517e+03
#
# =============================
#
#
# =============================
# Iteration 105 complete
#
#
# scaled || r || = 1.065e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.215e+03
# Cost function:         6.464e+03
#
# =============================
#
#
# =============================
# Iteration 106 complete
#
#
# scaled || r || = 1.060e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.165e+03
# Cost function:         6.412e+03
#
# =============================
#
#
# =============================
# Iteration 107 complete
#
#
# scaled || r || = 1.055e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.117e+03
# Cost function:         6.361e+03
#
# =============================
#
#
# =============================
# Iteration 108 complete
#
#
# scaled || r || = 1.050e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.067e+03
# Cost function:         6.309e+03
#
# =============================
#
#
# =============================
# Iteration 109 complete
#
#
# scaled || r || = 1.045e-02, delta = 5.072e-09
# Max-qnorm upper bound: 6.019e+03
# Cost function:         6.259e+03
#
# =============================
#
#
# =============================
# Iteration 110 complete
#
#
# scaled || r || = 1.040e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.970e+03
# Cost function:         6.209e+03
#
# =============================
#
#
# =============================
# Iteration 111 complete
#
#
# scaled || r || = 1.035e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.925e+03
# Cost function:         6.161e+03
#
# =============================
#
#
# =============================
# Iteration 112 complete
#
#
# scaled || r || = 1.031e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.880e+03
# Cost function:         6.115e+03
#
# =============================
#
#
# =============================
# Iteration 113 complete
#
#
# scaled || r || = 1.026e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.834e+03
# Cost function:         6.067e+03
#
# =============================
#
#
# =============================
# Iteration 114 complete
#
#
# scaled || r || = 1.022e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.792e+03
# Cost function:         6.022e+03
#
# =============================
#
#
# =============================
# Iteration 115 complete
#
#
# scaled || r || = 1.017e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.747e+03
# Cost function:         5.975e+03
#
# =============================
#
#
# =============================
# Iteration 116 complete
#
#
# scaled || r || = 1.013e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.706e+03
# Cost function:         5.933e+03
#
# =============================
#
#
# =============================
# Iteration 117 complete
#
#
# scaled || r || = 1.009e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.663e+03
# Cost function:         5.888e+03
#
# =============================
#
#
# =============================
# Iteration 118 complete
#
#
# scaled || r || = 1.005e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.623e+03
# Cost function:         5.847e+03
#
# =============================
#
#
# =============================
# Iteration 119 complete
#
#
# scaled || r || = 1.001e-02, delta = 5.072e-09
# Max-qnorm upper bound: 5.582e+03
# Cost function:         5.803e+03
#
# =============================
#
#
# =============================
# Iteration 120 complete
#
#
# scaled || r || = 9.969e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.543e+03
# Cost function:         5.764e+03
#
# =============================
#
#
# =============================
# Iteration 121 complete
#
#
# scaled || r || = 9.927e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.503e+03
# Cost function:         5.721e+03
#
# =============================
#
#
# =============================
# Iteration 122 complete
#
#
# scaled || r || = 9.890e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.465e+03
# Cost function:         5.682e+03
#
# =============================
#
#
# =============================
# Iteration 123 complete
#
#
# scaled || r || = 9.850e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.427e+03
# Cost function:         5.642e+03
#
# =============================
#
#
# =============================
# Iteration 124 complete
#
#
# scaled || r || = 9.808e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.387e+03
# Cost function:         5.601e+03
#
# =============================
# =============================
# Iteration 125 complete
#
#
# scaled || r || = 9.768e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.348e+03
# Cost function:         5.560e+03
#
# =============================
#
#
# =============================
# Iteration 126 complete
#
#
# scaled || r || = 9.729e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.311e+03
# Cost function:         5.521e+03
#
# =============================
#
#
# =============================
# Iteration 127 complete
#
#
# scaled || r || = 9.690e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.272e+03
# Cost function:         5.481e+03
#
# =============================
#
#
# =============================
# Iteration 128 complete
#
#
# scaled || r || = 9.652e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.236e+03
# Cost function:         5.444e+03
#
# =============================
#
#
# =============================
# Iteration 129 complete
#
#
# scaled || r || = 9.613e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.198e+03
# Cost function:         5.405e+03
#
# =============================
#
#
# =============================
# Iteration 130 complete
#
#
# scaled || r || = 9.576e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.162e+03
# Cost function:         5.367e+03
#
# =============================
#
#
# =============================
# Iteration 131 complete
#
#
# scaled || r || = 9.538e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.126e+03
# Cost function:         5.329e+03
#
# =============================
#
#
# =============================
# Iteration 132 complete
#
#
# scaled || r || = 9.504e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.092e+03
# Cost function:         5.294e+03
#
# =============================
#
#
# =============================
# Iteration 133 complete
#
#
# scaled || r || = 9.468e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.057e+03
# Cost function:         5.257e+03
#
# =============================
#
#
# =============================
# Iteration 134 complete
#
#
# scaled || r || = 9.434e-03, delta = 5.072e-09
# Max-qnorm upper bound: 5.023e+03
# Cost function:         5.222e+03
#
# =============================
#
#
# =============================
# Iteration 135 complete
#
#
# scaled || r || = 9.398e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.989e+03
# Cost function:         5.187e+03
#
# =============================
#
#
# =============================
# Iteration 136 complete
#
#
# scaled || r || = 9.365e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.956e+03
# Cost function:         5.153e+03
#
# =============================
#
#
# =============================
# Iteration 137 complete
#
#
# scaled || r || = 9.330e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.922e+03
# Cost function:         5.118e+03
#
# =============================
#
#
# =============================
# Iteration 138 complete
#
#
# scaled || r || = 9.298e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.891e+03
# Cost function:         5.085e+03
#
# =============================
#
#
# =============================
# Iteration 139 complete
#
#
# scaled || r || = 9.264e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.858e+03
# Cost function:         5.051e+03
#
# =============================
#
#
# =============================
# Iteration 140 complete
#
#
# scaled || r || = 9.232e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.828e+03
# Cost function:         5.020e+03
#
# =============================
#
#
# =============================
# Iteration 141 complete
#
#
# scaled || r || = 9.199e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.796e+03
# Cost function:         4.986e+03
#
# =============================
#
#
# =============================
# Iteration 142 complete
#
#
# scaled || r || = 9.168e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.766e+03
# Cost function:         4.955e+03
#
# =============================
#
#
# =============================
# Iteration 143 complete
#
#
# scaled || r || = 9.136e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.735e+03
# Cost function:         4.923e+03
#
# =============================
#
#
# =============================
# Iteration 144 complete
#
#
# scaled || r || = 9.106e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.706e+03
# Cost function:         4.893e+03
#
# =============================
#
#
# =============================
# Iteration 145 complete
#
#
# scaled || r || = 9.075e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.675e+03
# Cost function:         4.861e+03
#
# =============================
#
#
# =============================
# Iteration 146 complete
#
#
# scaled || r || = 9.046e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.646e+03
# Cost function:         4.830e+03
#
# =============================
#
#
# =============================
# Iteration 147 complete
#
#
# scaled || r || = 9.014e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.616e+03
# Cost function:         4.800e+03
#
# =============================
#
#
# =============================
# Iteration 148 complete
#
#
# scaled || r || = 8.984e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.588e+03
# Cost function:         4.770e+03
#
# =============================
#
#
# =============================
# Iteration 149 complete
#
#
# scaled || r || = 8.956e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.560e+03
# Cost function:         4.742e+03
#
# =============================
#
#
# =============================
# Iteration 150 complete
#
#
# scaled || r || = 8.927e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.531e+03
# Cost function:         4.712e+03
#
# =============================
#
#
# =============================
# Iteration 151 complete
#
#
# scaled || r || = 8.899e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.505e+03
# Cost function:         4.684e+03
#
# =============================
#
#
# =============================
# Iteration 152 complete
#
#
# scaled || r || = 8.869e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.477e+03
# Cost function:         4.655e+03
#
# =============================
#
#
# =============================
# Iteration 153 complete
#
#
# scaled || r || = 8.840e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.450e+03
# Cost function:         4.627e+03
#
# =============================
#
#
# =============================
# Iteration 154 complete
#
#
# scaled || r || = 8.813e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.424e+03
# Cost function:         4.600e+03
#
# =============================
#
#
# =============================
# Iteration 155 complete
#
#
# scaled || r || = 8.785e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.398e+03
# Cost function:         4.573e+03
#
# =============================
#
#
# =============================
# Iteration 156 complete
#
#
# scaled || r || = 8.758e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.372e+03
# Cost function:         4.546e+03
#
# =============================
#
#
# =============================
# Iteration 157 complete
#
#
# scaled || r || = 8.732e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.346e+03
# Cost function:         4.519e+03
#
# =============================
#
#
# =============================
# Iteration 158 complete
#
#
# scaled || r || = 8.706e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.321e+03
# Cost function:         4.494e+03
#
# =============================
#
#
# =============================
# Iteration 159 complete
#
#
# scaled || r || = 8.679e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.296e+03
# Cost function:         4.468e+03
#
# =============================
#
#
# =============================
# Iteration 160 complete
#
#
# scaled || r || = 8.654e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.272e+03
# Cost function:         4.443e+03
#
# =============================
#
#
# =============================
# Iteration 161 complete
#
#
# scaled || r || = 8.627e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.248e+03
# Cost function:         4.418e+03
#
# =============================
#
#
# =============================
# Iteration 162 complete
#
#
# scaled || r || = 8.602e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.224e+03
# Cost function:         4.393e+03
#
# =============================
#
#
# =============================
# Iteration 163 complete
#
#
# scaled || r || = 8.580e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.201e+03
# Cost function:         4.369e+03
#
# =============================
#
#
# =============================
# Iteration 164 complete
#
#
# scaled || r || = 8.552e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.178e+03
# Cost function:         4.345e+03
#
# =============================
#
#
# =============================
# Iteration 165 complete
#
#
# scaled || r || = 8.528e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.155e+03
# Cost function:         4.321e+03
#
# =============================
# =============================
# Iteration 166 complete
#
#
# scaled || r || = 8.503e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.131e+03
# Cost function:         4.297e+03
#
# =============================
#
#
# =============================
# Iteration 167 complete
#
#
# scaled || r || = 8.476e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.108e+03
# Cost function:         4.273e+03
#
# =============================
#
#
# =============================
# Iteration 168 complete
#
#
# scaled || r || = 8.454e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.086e+03
# Cost function:         4.250e+03
#
# =============================
#
#
# =============================
# Iteration 169 complete
#
#
# scaled || r || = 8.428e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.064e+03
# Cost function:         4.226e+03
#
# =============================
#
#
# =============================
# Iteration 170 complete
#
#
# scaled || r || = 8.406e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.042e+03
# Cost function:         4.204e+03
#
# =============================
#
#
# =============================
# Iteration 171 complete
#
#
# scaled || r || = 8.378e-03, delta = 5.072e-09
# Max-qnorm upper bound: 4.020e+03
# Cost function:         4.181e+03
#
# =============================
#
#
# =============================
# Iteration 172 complete
#
#
# scaled || r || = 8.355e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.999e+03
# Cost function:         4.159e+03
#
# =============================
#
#
# =============================
# Iteration 173 complete
#
#
# scaled || r || = 8.334e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.978e+03
# Cost function:         4.137e+03
#
# =============================
#
#
# =============================
# Iteration 174 complete
#
#
# scaled || r || = 8.310e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.958e+03
# Cost function:         4.117e+03
#
# =============================
#
#
# =============================
# Iteration 175 complete
#
#
# scaled || r || = 8.285e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.937e+03
# Cost function:         4.095e+03
#
# =============================
#
#
# =============================
# Iteration 176 complete
#
#
# scaled || r || = 8.262e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.917e+03
# Cost function:         4.074e+03
#
# =============================
#
#
# =============================
# Iteration 177 complete
#
#
# scaled || r || = 8.242e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.898e+03
# Cost function:         4.054e+03
#
# =============================
#
#
# =============================
# Iteration 178 complete
#
#
# scaled || r || = 8.220e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.878e+03
# Cost function:         4.034e+03
#
# =============================
#
#
# =============================
# Iteration 179 complete
#
#
# scaled || r || = 8.199e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.859e+03
# Cost function:         4.014e+03
#
# =============================
#
#
# =============================
# Iteration 180 complete
#
#
# scaled || r || = 8.177e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.840e+03
# Cost function:         3.994e+03
#
# =============================
#
#
# =============================
# Iteration 181 complete
#
#
# scaled || r || = 8.155e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.821e+03
# Cost function:         3.974e+03
#
# =============================
#
#
# =============================
# Iteration 182 complete
#
#
# scaled || r || = 8.133e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.802e+03
# Cost function:         3.955e+03
#
# =============================
#
#
# =============================
# Iteration 183 complete
#
#
# scaled || r || = 8.113e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.784e+03
# Cost function:         3.936e+03
#
# =============================
#
#
# =============================
# Iteration 184 complete
#
#
# scaled || r || = 8.092e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.766e+03
# Cost function:         3.917e+03
#
# =============================
#
#
# =============================
# Iteration 185 complete
#
#
# scaled || r || = 8.072e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.749e+03
# Cost function:         3.899e+03
#
# =============================
#
#
# =============================
# Iteration 186 complete
#
#
# scaled || r || = 8.050e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.731e+03
# Cost function:         3.881e+03
#
# =============================
#
#
# =============================
# Iteration 187 complete
#
#
# scaled || r || = 8.029e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.714e+03
# Cost function:         3.863e+03
#
# =============================
#
#
# =============================
# Iteration 188 complete
#
#
# scaled || r || = 8.008e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.696e+03
# Cost function:         3.845e+03
#
# =============================
#
#
# =============================
# Iteration 189 complete
#
#
# scaled || r || = 7.988e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.680e+03
# Cost function:         3.828e+03
#
# =============================
#
#
# =============================
# Iteration 190 complete
#
#
# scaled || r || = 7.968e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.662e+03
# Cost function:         3.810e+03
#
# =============================
#
#
# =============================
# Iteration 191 complete
#
#
# scaled || r || = 7.947e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.645e+03
# Cost function:         3.792e+03
#
# =============================
#
#
# =============================
# Iteration 192 complete
#
#
# scaled || r || = 7.928e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.629e+03
# Cost function:         3.775e+03
#
# =============================
#
#
# =============================
# Iteration 193 complete
#
#
# scaled || r || = 7.909e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.612e+03
# Cost function:         3.758e+03
#
# =============================
#
#
# =============================
# Iteration 194 complete
#
#
# scaled || r || = 7.889e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.595e+03
# Cost function:         3.740e+03
#
# =============================
#
#
# =============================
# Iteration 195 complete
#
#
# scaled || r || = 7.871e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.580e+03
# Cost function:         3.724e+03
#
# =============================
#
#
# =============================
# Iteration 196 complete
#
#
# scaled || r || = 7.850e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.563e+03
# Cost function:         3.707e+03
#
# =============================
#
#
# =============================
# Iteration 197 complete
#
#
# scaled || r || = 7.830e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.547e+03
# Cost function:         3.690e+03
#
# =============================
#
#
# =============================
# Iteration 198 complete
#
#
# scaled || r || = 7.811e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.532e+03
# Cost function:         3.674e+03
#
# =============================
#
#
# =============================
# Iteration 199 complete
#
#
# scaled || r || = 7.793e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.517e+03
# Cost function:         3.658e+03
#
# =============================
#
#
# =============================
# Iteration 200 complete
#
#
# scaled || r || = 7.775e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.501e+03
# Cost function:         3.642e+03
#
# =============================
#
#
# =============================
# Iteration 201 complete
#
#
# scaled || r || = 7.757e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.486e+03
# Cost function:         3.627e+03
#
# =============================
#
#
# =============================
# Iteration 202 complete
#
#
# scaled || r || = 7.739e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.472e+03
# Cost function:         3.611e+03
#
# =============================
#
#
# =============================
# Iteration 203 complete
#
#
# scaled || r || = 7.722e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.457e+03
# Cost function:         3.596e+03
#
# =============================
#
#
# =============================
# Iteration 204 complete
#
#
# scaled || r || = 7.705e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.442e+03
# Cost function:         3.581e+03
#
# =============================
#
#
# =============================
# Iteration 205 complete
#
#
# scaled || r || = 7.688e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.428e+03
# Cost function:         3.566e+03
#
# =============================
#
#
# =============================
# Iteration 206 complete
#
#
# scaled || r || = 7.671e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.413e+03
# Cost function:         3.551e+03
#
# =============================
# =============================
# Iteration 207 complete
#
#
# scaled || r || = 7.654e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.399e+03
# Cost function:         3.536e+03
#
# =============================
#
#
# =============================
# Iteration 208 complete
#
#
# scaled || r || = 7.638e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.385e+03
# Cost function:         3.521e+03
#
# =============================
#
#
# =============================
# Iteration 209 complete
#
#
# scaled || r || = 7.622e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.371e+03
# Cost function:         3.507e+03
#
# =============================
#
#
# =============================
# Iteration 210 complete
#
#
# scaled || r || = 7.604e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.357e+03
# Cost function:         3.492e+03
#
# =============================
#
#
# =============================
# Iteration 211 complete
#
#
# scaled || r || = 7.587e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.343e+03
# Cost function:         3.478e+03
#
# =============================
#
#
# =============================
# Iteration 212 complete
#
#
# scaled || r || = 7.570e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.329e+03
# Cost function:         3.464e+03
#
# =============================
#
#
# =============================
# Iteration 213 complete
#
#
# scaled || r || = 7.554e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.316e+03
# Cost function:         3.450e+03
#
# =============================
#
#
# =============================
# Iteration 214 complete
#
#
# scaled || r || = 7.537e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.302e+03
# Cost function:         3.436e+03
#
# =============================
#
#
# =============================
# Iteration 215 complete
#
#
# scaled || r || = 7.521e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.289e+03
# Cost function:         3.422e+03
#
# =============================
#
#
# =============================
# Iteration 216 complete
#
#
# scaled || r || = 7.505e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.275e+03
# Cost function:         3.408e+03
#
# =============================
#
#
# =============================
# Iteration 217 complete
#
#
# scaled || r || = 7.490e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.262e+03
# Cost function:         3.394e+03
#
# =============================
#
#
# =============================
# Iteration 218 complete
#
#
# scaled || r || = 7.474e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.249e+03
# Cost function:         3.381e+03
#
# =============================
#
#
# =============================
# Iteration 219 complete
#
#
# scaled || r || = 7.459e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.236e+03
# Cost function:         3.367e+03
#
# =============================
#
#
# =============================
# Iteration 220 complete
#
#
# scaled || r || = 7.444e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.223e+03
# Cost function:         3.354e+03
#
# =============================
#
#
# =============================
# Iteration 221 complete
#
#
# scaled || r || = 7.429e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.210e+03
# Cost function:         3.340e+03
#
# =============================
#
#
# =============================
# Iteration 222 complete
#
#
# scaled || r || = 7.414e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.197e+03
# Cost function:         3.327e+03
#
# =============================
#
#
# =============================
# Iteration 223 complete
#
#
# scaled || r || = 7.400e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.185e+03
# Cost function:         3.314e+03
#
# =============================
#
#
# =============================
# Iteration 224 complete
#
#
# scaled || r || = 7.385e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.172e+03
# Cost function:         3.301e+03
#
# =============================
#
#
# =============================
# Iteration 225 complete
#
#
# scaled || r || = 7.370e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.159e+03
# Cost function:         3.287e+03
#
# =============================
#
#
# =============================
# Iteration 226 complete
#
#
# scaled || r || = 7.354e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.146e+03
# Cost function:         3.274e+03
#
# =============================
#
#
# =============================
# Iteration 227 complete
#
#
# scaled || r || = 7.340e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.133e+03
# Cost function:         3.260e+03
#
# =============================
#
#
# =============================
# Iteration 228 complete
#
#
# scaled || r || = 7.324e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.120e+03
# Cost function:         3.247e+03
#
# =============================
#
#
# =============================
# Iteration 229 complete
#
#
# scaled || r || = 7.310e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.107e+03
# Cost function:         3.234e+03
#
# =============================
#
#
# =============================
# Iteration 230 complete
#
#
# scaled || r || = 7.295e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.095e+03
# Cost function:         3.221e+03
#
# =============================
#
#
# =============================
# Iteration 231 complete
#
#
# scaled || r || = 7.280e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.082e+03
# Cost function:         3.208e+03
#
# =============================
#
#
# =============================
# Iteration 232 complete
#
#
# scaled || r || = 7.265e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.070e+03
# Cost function:         3.195e+03
#
# =============================
#
#
# =============================
# Iteration 233 complete
#
#
# scaled || r || = 7.250e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.057e+03
# Cost function:         3.182e+03
#
# =============================
#
#
# =============================
# Iteration 234 complete
#
#
# scaled || r || = 7.235e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.045e+03
# Cost function:         3.170e+03
#
# =============================
#
#
# =============================
# Iteration 235 complete
#
#
# scaled || r || = 7.221e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.033e+03
# Cost function:         3.157e+03
#
# =============================
#
#
# =============================
# Iteration 236 complete
#
#
# scaled || r || = 7.207e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.021e+03
# Cost function:         3.144e+03
#
# =============================
#
#
# =============================
# Iteration 237 complete
#
#
# scaled || r || = 7.193e-03, delta = 5.072e-09
# Max-qnorm upper bound: 3.009e+03
# Cost function:         3.132e+03
#
# =============================
#
#
# =============================
# Iteration 238 complete
#
#
# scaled || r || = 7.179e-03, delta = 5.072e-09
# Max-qnorm upper bound: 2.997e+03
# Cost function:         3.119e+03
#
# =============================
#
#
# =============================
# Iteration 239 complete
#
#
# scaled || r || = 7.165e-03, delta = 5.072e-09
# Max-qnorm upper bound: 2.985e+03
# Cost function:         3.107e+03
#
# ...
#
# =============================
#
#
# =============================
# Iteration 221 complete
#
#
# scaled || r || = 8.745e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.712e+03
# Cost function:         3.882e+03
#
# =============================
#
#
# =============================
# Iteration 222 complete
#
#
# scaled || r || = 8.726e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.698e+03
# Cost function:         3.868e+03
#
# =============================
#
#
# =============================
# Iteration 223 complete
#
#
# scaled || r || = 8.703e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.685e+03
# Cost function:         3.854e+03
#
# =============================
#
#
# =============================
# Iteration 224 complete
#
#
# scaled || r || = 8.683e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.671e+03
# Cost function:         3.840e+03
#
# =============================
#
#
# =============================
# Iteration 225 complete
#
#
# scaled || r || = 8.661e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.658e+03
# Cost function:         3.825e+03
#
# =============================
#
#
# =============================
# Iteration 226 complete
#
#
# scaled || r || = 8.642e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.645e+03
# Cost function:         3.812e+03
#
# =============================
#
#
# =============================
# Iteration 227 complete
#
#
# scaled || r || = 8.620e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.631e+03
# Cost function:         3.798e+03
#
# =============================
#
#
# =============================
# Iteration 228 complete
#
#
# scaled || r || = 8.602e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.619e+03
# Cost function:         3.784e+03
#
# =============================
#
#
# =============================
# Iteration 229 complete
#
#
# scaled || r || = 8.580e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.606e+03
# Cost function:         3.770e+03
#
# =============================
#
#
# =============================
# Iteration 230 complete
#
#
# scaled || r || = 8.561e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.593e+03
# Cost function:         3.757e+03
#
# =============================
#
#
# =============================
# Iteration 231 complete
#
#
# scaled || r || = 8.539e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.580e+03
# Cost function:         3.743e+03
#
# =============================
#
#
# =============================
# Iteration 232 complete
#
#
# scaled || r || = 8.519e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.567e+03
# Cost function:         3.730e+03
#
# =============================
#
#
# =============================
# Iteration 233 complete
#
#
# scaled || r || = 8.501e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.555e+03
# Cost function:         3.717e+03
#
# =============================
#
#
# =============================
# Iteration 234 complete
#
#
# scaled || r || = 8.480e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.542e+03
# Cost function:         3.703e+03
#
# =============================
#
#
# =============================
# Iteration 235 complete
#
#
# scaled || r || = 8.462e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.530e+03
# Cost function:         3.690e+03
#
# =============================
#
#
# =============================
# Iteration 236 complete
#
#
# scaled || r || = 8.441e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.517e+03
# Cost function:         3.677e+03
#
# =============================
#
#
# =============================
# Iteration 237 complete
#
#
# scaled || r || = 8.422e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.504e+03
# Cost function:         3.664e+03
#
# =============================
#
#
# =============================
# Iteration 238 complete
#
#
# scaled || r || = 8.404e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.492e+03
# Cost function:         3.651e+03
#
# =============================
#
#
# =============================
# Iteration 239 complete
#
#
# scaled || r || = 8.384e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.480e+03
# Cost function:         3.638e+03
#
# =============================
#
#
# =============================
# Iteration 240 complete
#
#
# scaled || r || = 8.367e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.468e+03
# Cost function:         3.626e+03
#
# =============================
#
#
# =============================
# Iteration 241 complete
#
#
# scaled || r || = 8.347e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.456e+03
# Cost function:         3.613e+03
#
# =============================
#
#
# =============================
# Iteration 242 complete
#
#
# scaled || r || = 8.327e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.444e+03
# Cost function:         3.600e+03
#
# =============================
#
#
# =============================
# Iteration 243 complete
#
#
# scaled || r || = 8.311e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.432e+03
# Cost function:         3.588e+03
#
# =============================
#
#
# =============================
# Iteration 244 complete
#
#
# scaled || r || = 8.291e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.420e+03
# Cost function:         3.575e+03
#
# =============================
#
#
# =============================
# Iteration 245 complete
#
#
# scaled || r || = 8.272e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.408e+03
# Cost function:         3.562e+03
#
# =============================
#
#
# =============================
# Iteration 246 complete
#
#
# scaled || r || = 8.256e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.397e+03
# Cost function:         3.550e+03
#
# =============================
#
#
# =============================
# Iteration 247 complete
#
#
# scaled || r || = 8.237e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.385e+03
# Cost function:         3.538e+03
#
# =============================
#
#
# =============================
# Iteration 248 complete
#
#
# scaled || r || = 8.218e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.373e+03
# Cost function:         3.526e+03
#
# =============================
#
#
# =============================
# Iteration 249 complete
#
#
# scaled || r || = 8.203e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.362e+03
# Cost function:         3.514e+03
#
# =============================
#
#
# =============================
# Iteration 250 complete
#
#
# scaled || r || = 8.184e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.350e+03
# Cost function:         3.502e+03
#
# =============================
#
#
# =============================
# Iteration 251 complete
#
#
# scaled || r || = 8.166e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.339e+03
# Cost function:         3.490e+03
#
# =============================
#
#
# =============================
# Iteration 252 complete
#
#
# scaled || r || = 8.150e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.328e+03
# Cost function:         3.478e+03
#
# =============================
#
#
# =============================
# Iteration 253 complete
#
#
# scaled || r || = 8.132e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.316e+03
# Cost function:         3.466e+03
#
# =============================
# =============================
# Iteration 254 complete
#
#
# scaled || r || = 8.114e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.305e+03
# Cost function:         3.454e+03
#
# =============================
#
#
# =============================
# Iteration 255 complete
#
#
# scaled || r || = 8.099e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.294e+03
# Cost function:         3.443e+03
#
# =============================
#
#
# =============================
# Iteration 256 complete
#
#
# scaled || r || = 8.081e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.283e+03
# Cost function:         3.431e+03
#
# =============================
#
#
# =============================
# Iteration 257 complete
#
#
# scaled || r || = 8.063e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.272e+03
# Cost function:         3.419e+03
#
# =============================
#
#
# =============================
# Iteration 258 complete
#
#
# scaled || r || = 8.048e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.261e+03
# Cost function:         3.408e+03
#
# =============================
#
#
# =============================
# Iteration 259 complete
#
#
# scaled || r || = 8.031e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.250e+03
# Cost function:         3.397e+03
#
# =============================
#
#
# =============================
# Iteration 260 complete
#
#
# scaled || r || = 8.014e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.240e+03
# Cost function:         3.385e+03
#
# =============================
#
#
# =============================
# Iteration 261 complete
#
#
# scaled || r || = 7.999e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.229e+03
# Cost function:         3.374e+03
#
# =============================
#
#
# =============================
# Iteration 262 complete
#
#
# scaled || r || = 7.982e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.218e+03
# Cost function:         3.363e+03
#
# =============================
#
#
# =============================
# Iteration 263 complete
#
#
# scaled || r || = 7.965e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.208e+03
# Cost function:         3.352e+03
#
# =============================
#
#
# =============================
# Iteration 264 complete
#
#
# scaled || r || = 7.951e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.197e+03
# Cost function:         3.341e+03
#
# =============================
#
#
# =============================
# Iteration 265 complete
#
#
# scaled || r || = 7.934e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.187e+03
# Cost function:         3.330e+03
#
# =============================
#
#
# =============================
# Iteration 266 complete
#
#
# scaled || r || = 7.918e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.176e+03
# Cost function:         3.319e+03
#
# =============================
#
#
# =============================
# Iteration 267 complete
#
#
# scaled || r || = 7.904e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.166e+03
# Cost function:         3.308e+03
#
# =============================
#
#
# =============================
# Iteration 268 complete
#
#
# scaled || r || = 7.887e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.156e+03
# Cost function:         3.297e+03
#
# =============================
#
#
# =============================
# Iteration 269 complete
#
#
# scaled || r || = 7.871e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.145e+03
# Cost function:         3.286e+03
#
# =============================
#
#
# =============================
# Iteration 270 complete
#
#
# scaled || r || = 7.857e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.135e+03
# Cost function:         3.276e+03
#
# =============================
#
#
# =============================
# Iteration 271 complete
#
#
# scaled || r || = 7.841e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.125e+03
# Cost function:         3.265e+03
#
# =============================
#
#
# =============================
# Iteration 272 complete
#
#
# scaled || r || = 7.825e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.115e+03
# Cost function:         3.255e+03
#
# =============================
#
#
# =============================
# Iteration 273 complete
#
#
# scaled || r || = 7.812e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.105e+03
# Cost function:         3.244e+03
#
# =============================
#
#
# =============================
# Iteration 274 complete
#
#
# scaled || r || = 7.796e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.095e+03
# Cost function:         3.234e+03
#
# =============================
#
#
# =============================
# Iteration 275 complete
#
#
# scaled || r || = 7.781e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.085e+03
# Cost function:         3.223e+03
#
# =============================
#
#
# =============================
# Iteration 276 complete
#
#
# scaled || r || = 7.768e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.076e+03
# Cost function:         3.214e+03
#
# =============================
#
#
# =============================
# Iteration 277 complete
#
#
# scaled || r || = 7.752e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.066e+03
# Cost function:         3.203e+03
#
# =============================
#
#
# =============================
# Iteration 278 complete
#
#
# scaled || r || = 7.737e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.056e+03
# Cost function:         3.193e+03
#
# =============================
#
#
# =============================
# Iteration 279 complete
#
#
# scaled || r || = 7.724e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.047e+03
# Cost function:         3.183e+03
#
# =============================
#
#
# =============================
# Iteration 280 complete
#
#
# scaled || r || = 7.709e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.037e+03
# Cost function:         3.173e+03
#
# =============================
#
#
# =============================
# Iteration 281 complete
#
#
# scaled || r || = 7.694e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.027e+03
# Cost function:         3.163e+03
#
# =============================
#
#
# =============================
# Iteration 282 complete
#
#
# scaled || r || = 7.682e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.018e+03
# Cost function:         3.153e+03
#
# =============================
#
#
# =============================
# Iteration 283 complete
#
#
# scaled || r || = 7.667e-03, delta = 5.072e-06
# Max-qnorm upper bound: 3.009e+03
# Cost function:         3.143e+03
#
# =============================
#
#
# =============================
# Iteration 284 complete
#
#
# scaled || r || = 7.652e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.999e+03
# Cost function:         3.133e+03
#
# =============================
#
#
# =============================
# Iteration 285 complete
#
#
# scaled || r || = 7.640e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.990e+03
# Cost function:         3.124e+03
#
# =============================
#
#
# =============================
# Iteration 286 complete
#
#
# scaled || r || = 7.626e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.981e+03
# Cost function:         3.114e+03
#
# =============================
#
#
# =============================
# Iteration 287 complete
#
#
# scaled || r || = 7.611e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.972e+03
# Cost function:         3.104e+03
#
# =============================
#
#
# =============================
# Iteration 288 complete
#
#
# scaled || r || = 7.599e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.963e+03
# Cost function:         3.095e+03
#
# =============================
#
#
# =============================
# Iteration 289 complete
#
#
# scaled || r || = 7.585e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.954e+03
# Cost function:         3.086e+03
#
# =============================
#
#
# =============================
# Iteration 290 complete
#
#
# scaled || r || = 7.571e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.944e+03
# Cost function:         3.076e+03
#
# =============================
#
#
# =============================
# Iteration 291 complete
#
#
# scaled || r || = 7.560e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.936e+03
# Cost function:         3.067e+03
#
# =============================
#
#
# =============================
# Iteration 292 complete
#
#
# scaled || r || = 7.545e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.927e+03
# Cost function:         3.057e+03
#
# =============================
#
#
# =============================
# Iteration 293 complete
#
#
# scaled || r || = 7.532e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.918e+03
# Cost function:         3.048e+03
#
# =============================
#
#
# =============================
# Iteration 294 complete
#
#
# scaled || r || = 7.520e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.909e+03
# Cost function:         3.039e+03
#
# =============================
# =============================
# Iteration 295 complete
#
#
# scaled || r || = 7.507e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.900e+03
# Cost function:         3.030e+03
#
# =============================
#
#
# =============================
# Iteration 296 complete
#
#
# scaled || r || = 7.493e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.891e+03
# Cost function:         3.021e+03
#
# =============================
#
#
# =============================
# Iteration 297 complete
#
#
# scaled || r || = 7.482e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.883e+03
# Cost function:         3.012e+03
#
# =============================
#
#
# =============================
# Iteration 298 complete
#
#
# scaled || r || = 7.468e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.874e+03
# Cost function:         3.003e+03
#
# =============================
#
#
# =============================
# Iteration 299 complete
#
#
# scaled || r || = 7.455e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.866e+03
# Cost function:         2.994e+03
#
# =============================
#
#
# finished in 300 iterations
#
#
# scaled || r || = 7.455e-03, delta = 5.072e-06
# Max-qnorm upper bound: 2.866e+03
# Cost function:         2.994e+03

# %%
qnorm_max = max_qnorm_ub(Unew2)
print(qnorm_max)
# Out:
# 2865.6058623923414

# %%
expander_eigs = np.abs(nx.linalg.adjacency_spectrum(expander))
expander_eigs.sort()
print(expander_eigs[-10:])
# Out:
# [2.76624618 2.82519566 2.88752242 2.98148777 3.27845939 3.31049253
#  3.46167591 3.6584745  4.04131438 6.        ]

# %%
bound = 2**(2*t-4) * 1.8**(t-1) * (qnorm_max + qnorm_true)**2 * ((1 + expander_eigs[-2]/expander_eigs[-1])**(t-1) - 1)
print(bound)
print(bound / n**t)
# Out:
# 39057183794.38429
# 1607.291514172193

# %%
for i in range(len(Unew2_list)):
    print("delta = {}".format(deltas[i]))
    print("loss of U true:     %.3e" % np.sqrt(loss(U, data) / data.nnz))
    print("loss of U max:      %.3e\n" % np.sqrt(loss(Unew2_list[i], data) / data.nnz))
# Out:
# delta = 1e-06
# loss of U true:     4.984e-03
# loss of U max:      6.544e-03
#
# delta = 1e-05
# loss of U true:     4.984e-03
# loss of U max:      7.768e-03
#
# delta = 0.0001
# loss of U true:     4.984e-03
# loss of U max:      6.041e-03
#
# delta = 0.001
# loss of U true:     4.984e-03
# loss of U max:      7.455e-03

# %%
import matplotlib.pyplot as plt

plt.semilogy(cost_arr_list[0])
plt.semilogy(cost_arr_list[1])
plt.semilogy(cost_arr_list[2])
plt.semilogy(cost_arr_list[3])
# plt.semilogy(cost_arr_list[4])
# plt.semilogy(cost_arr_list[5])

plt.legend(["delta = 1e-6", "delta = 1e-5", "delta = 1e-4", "delta = 1e-3"])
plt.xlabel('iterate')
plt.ylabel('cost')
plt.title("Cost-Curve for Various Delta Values")
plt.savefig('Cost-Curve-Delta_300.png')

# %% [markdown]
# ## Generalization error

# %%
def gen_err(Upred, Utrue):
    norm_true = kr_dot(Utrue, Utrue)
    mse_gen = kr_dot(Upred, Upred) + norm_true - 2 * kr_dot(Upred, Utrue)
    return np.sqrt(mse_gen / norm_true)

def mse_gen_err(Upred, Utrue):
    norm_true = kr_dot(Utrue, Utrue)
    mse_gen = kr_dot(Upred, Upred) + norm_true - 2 * kr_dot(Upred, Utrue)
    return np.sqrt(mse_gen / Upred[0].shape[0] ** len(Upred))


for i in range(len(Unew2_list)):
    print("delta = {}".format(deltas[i]))
    print("relative RMSE max:      %1.4e" % gen_err(Unew2_list[i], U))
    print("MSE max:                %1.4e\n" % mse_gen_err(Unew2_list[i], U))

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, axs = plt.subplots(1,t, figsize=(6, 20))
for i in range(t):
    im = axs[i].imshow(Unew2[i])
    divider = make_axes_locatable(axs[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
    if i > 0:
        axs[i].set_yticks([])

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, axs = plt.subplots(1,t, figsize=(6, 20))
for i in range(t):
    im = axs[i].imshow(U[i])
    divider = make_axes_locatable(axs[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
    if i > 0:
        axs[i].set_yticks([])
