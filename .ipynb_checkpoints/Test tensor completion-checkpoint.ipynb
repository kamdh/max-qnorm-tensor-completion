# %%
#import jax.numpy as np
#from jax import pmap
import numpy as np
from maxnorm.maxnorm_completion import *
from maxnorm.tenalg import *
from maxnorm.graphs import *
import sparse
from itertools import product
import networkx as nx

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %load_ext autoreload
# Out:
# C:\Users\AARea\Documents\IMPORTANT DOCS\SCHOOL\Graduate\Fall 2022\CSCI 692\max-qnorm-tensor-completion\maxnorm\maxnorm_completion.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if init is not 'alt_min':

# %%
# create random, low-rank tensor
t = 5
n = 30
r = 3
#delta = 0.1
const = 24
sigma = 0.005
ndata =  const * r * t * n * np.log10(n)
U = kr_random(n, t, r, rvs='unif')
U = kr_rescale(U, np.sqrt(n**t), 'hs')
norm_true = np.sqrt(kr_dot(U, U) / n**t)
#U = [np.random.randn(n, r) for i in range(t)]
print("n data: %.2e" % ndata)
print("n data ** t/2: %.2e" % int(const * r * n**(t/2) * np.log10(n)))
print("true norm: %.2e" % norm_true)
# Out:
# n data: 1.60e+04
# n data ** t/2: 5.24e+05
# true norm: 1.00e+00

# %%
qnorm_true = max_qnorm_ub(U)
print(qnorm_true)
print(r**(t/2))
# Out:
# 57.636359238931064
# 15.588457268119896

# %%
expander = nx.random_regular_graph(6, n)
#expander = nx.chordal_cycle_graph(n)
observation_mask = obs_mask_expander(expander, t)
#observation_mask = obs_mask_iid(tuple([n for i in range(t)]), ndata * n**(-t))

# %%
from run_sweep_iid import generate_data


data = generate_data(observation_mask, U, sigma)
clean_data_rmse = np.sqrt(loss(U, data) / data.nnz)
print(data.nnz)
print(ndata)
print(n**t)
print("%0.1e%%" % (float(data.nnz) / n**t * 100))
# Out:
# 38880
# 15952.909550972354
# 24300000
# 1.6e-01%

# %%
np.sqrt(data.sum()**2 / data.nnz)
# Out:
# 0.5733246018263322

# %%
data.coords
# Out:
# array([[ 0,  0,  0, ..., 29, 29, 29],
#        [ 8,  8,  8, ..., 18, 18, 18],
#        [ 0,  0,  0, ..., 29, 29, 29],
#        [ 8,  8,  8, ..., 18, 18, 18],
#        [ 0, 12, 13, ..., 13, 25, 29]])

# %%
delta = 1.5 * sigma
#np.sqrt(np.sum((data.data - clean_data)**2)) * 2 / np.sqrt(data.nnz) * 1.5

print("rms of data:        %f" % clean_data_rmse)
print("delta parameter:    %f" % delta)
print("rmse of U true:     %f" % np.sqrt(loss(U, data) / data.nnz))
# Out:
# rms of data:        0.004997
# delta parameter:    0.007500
# rmse of U true:     0.004997

# %%
# from tensorly.contrib.sparse.decomposition import parafac

# mask = data != 0
# core, factors = parafac(data, r, mask=mask, init='random', verbose=True, tol=1e-3, n_iter_max=8)
# scale_mat = np.diag(core.todense()**(1/t))
# U = [factors[i].todense() @ scale_mat for i in range(t)]

#Unew = [np.hstack((U, np.random.randn(n,r**(t-1)))) for U in Unew2]

# %%
# %autoreload
Unew1, cost_arr = tensor_completion_alt_min(data, 2 * r**t,
                                            #sgd=True, sgd_batch_size=2000,
                                            #U0 = Unew2,
                                            init='svdrand', 
                                            tol=1e-10, max_iter=100, verbosity=2)
# Out:
# Initial cost: 2.079e+04
# || r || = 1.034e+00
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 0 complete
# || resid || = 2.051e-01
# Cost :        1.809e+03
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 1 complete
# || resid || = 6.311e-02
# Cost :        7.888e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 2 complete
# || resid || = 4.007e-02
# Cost :        6.300e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 3 complete
# || resid || = 3.233e-02
# Cost :        5.616e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 4 complete
# || resid || = 2.794e-02
# Cost :        5.170e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 5 complete
# || resid || = 2.510e-02
# Cost :        4.839e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 6 complete
# || resid || = 2.302e-02
# Cost :        4.576e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 7 complete
# || resid || = 2.137e-02
# Cost :        4.352e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 8 complete
# || resid || = 2.015e-02
# Cost :        4.153e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 9 complete
# || resid || = 1.909e-02
# Cost :        3.979e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 10 complete
# || resid || = 1.849e-02
# Cost :        3.828e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 11 complete
# || resid || = 1.787e-02
# Cost :        3.692e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 12 complete
# || resid || = 1.748e-02
# Cost :        3.566e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 13 complete
# || resid || = 1.692e-02
# Cost :        3.452e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 14 complete
# || resid || = 1.653e-02
# Cost :        3.347e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 15 complete
# || resid || = 1.642e-02
# Cost :        3.250e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 16 complete
# || resid || = 1.622e-02
# Cost :        3.163e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 17 complete
# || resid || = 1.588e-02
# Cost :        3.081e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 18 complete
# || resid || = 1.577e-02
# Cost :        3.005e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 19 complete
# || resid || = 1.558e-02
# Cost :        2.938e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 20 complete
# || resid || = 1.543e-02
# Cost :        2.873e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 21 complete
# || resid || = 1.502e-02
# Cost :        2.810e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 22 complete
# || resid || = 1.492e-02
# Cost :        2.751e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 23 complete
# || resid || = 1.478e-02
# Cost :        2.696e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 24 complete
# || resid || = 1.478e-02
# Cost :        2.644e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 25 complete
# || resid || = 1.470e-02
# Cost :        2.594e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 26 complete
# || resid || = 1.463e-02
# Cost :        2.548e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
# =============================
# Iteration 27 complete
# || resid || = 1.446e-02
# Cost :        2.506e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 28 complete
# || resid || = 1.439e-02
# Cost :        2.464e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 29 complete
# || resid || = 1.417e-02
# Cost :        2.424e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 30 complete
# || resid || = 1.419e-02
# Cost :        2.385e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 31 complete
# || resid || = 1.416e-02
# Cost :        2.349e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 32 complete
# || resid || = 1.405e-02
# Cost :        2.315e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 33 complete
# || resid || = 1.402e-02
# Cost :        2.282e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 34 complete
# || resid || = 1.399e-02
# Cost :        2.250e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 35 complete
# || resid || = 1.380e-02
# Cost :        2.219e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 36 complete
# || resid || = 1.372e-02
# Cost :        2.189e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 37 complete
# || resid || = 1.368e-02
# Cost :        2.160e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 38 complete
# || resid || = 1.370e-02
# Cost :        2.134e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 39 complete
# || resid || = 1.363e-02
# Cost :        2.109e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 40 complete
# || resid || = 1.351e-02
# Cost :        2.084e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 41 complete
# || resid || = 1.351e-02
# Cost :        2.060e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 42 complete
# || resid || = 1.341e-02
# Cost :        2.037e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 43 complete
# || resid || = 1.335e-02
# Cost :        2.015e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 44 complete
# || resid || = 1.346e-02
# Cost :        1.992e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 45 complete
# || resid || = 1.333e-02
# Cost :        1.971e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 46 complete
# || resid || = 1.334e-02
# Cost :        1.950e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 47 complete
# || resid || = 1.322e-02
# Cost :        1.931e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 48 complete
# || resid || = 1.329e-02
# Cost :        1.911e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 49 complete
# || resid || = 1.328e-02
# Cost :        1.892e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 50 complete
# || resid || = 1.314e-02
# Cost :        1.874e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 51 complete
# || resid || = 1.304e-02
# Cost :        1.857e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 52 complete
# || resid || = 1.307e-02
# Cost :        1.839e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 53 complete
# || resid || = 1.303e-02
# Cost :        1.822e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 54 complete
# || resid || = 1.304e-02
# Cost :        1.805e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 55 complete
# || resid || = 1.305e-02
# Cost :        1.790e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 56 complete
# || resid || = 1.304e-02
# Cost :        1.773e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 57 complete
# || resid || = 1.298e-02
# Cost :        1.758e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 58 complete
# || resid || = 1.308e-02
# Cost :        1.743e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 59 complete
# || resid || = 1.301e-02
# Cost :        1.729e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 60 complete
# || resid || = 1.294e-02
# Cost :        1.715e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 61 complete
# || resid || = 1.284e-02
# Cost :        1.701e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 62 complete
# || resid || = 1.291e-02
# Cost :        1.687e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 63 complete
# || resid || = 1.279e-02
# Cost :        1.675e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 64 complete
# || resid || = 1.274e-02
# Cost :        1.662e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 65 complete
# || resid || = 1.273e-02
# Cost :        1.649e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 66 complete
# || resid || = 1.268e-02
# Cost :        1.637e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 67 complete
# || resid || = 1.263e-02
# Cost :        1.626e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 68 complete
# || resid || = 1.263e-02
# Cost :        1.614e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 69 complete
# || resid || = 1.254e-02
# Cost :        1.603e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 70 complete
# || resid || = 1.259e-02
# Cost :        1.591e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 71 complete
# || resid || = 1.259e-02
# Cost :        1.580e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 72 complete
# || resid || = 1.259e-02
# Cost :        1.569e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 73 complete
# || resid || = 1.254e-02
# Cost :        1.559e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 74 complete
# || resid || = 1.248e-02
# Cost :        1.548e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 75 complete
# || resid || = 1.234e-02
# Cost :        1.538e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 76 complete
# || resid || = 1.238e-02
# Cost :        1.527e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 77 complete
# || resid || = 1.235e-02
# Cost :        1.517e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 78 complete
# || resid || = 1.237e-02
# Cost :        1.508e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 79 complete
# || resid || = 1.231e-02
# Cost :        1.498e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 80 complete
# || resid || = 1.230e-02
# Cost :        1.489e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 81 complete
# || resid || = 1.220e-02
# Cost :        1.479e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 82 complete
# || resid || = 1.213e-02
# Cost :        1.470e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 83 complete
# || resid || = 1.215e-02
# Cost :        1.461e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 84 complete
# || resid || = 1.205e-02
# Cost :        1.453e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 85 complete
# || resid || = 1.208e-02
# Cost :        1.444e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 86 complete
# || resid || = 1.208e-02
# Cost :        1.435e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 87 complete
# || resid || = 1.205e-02
# Cost :        1.426e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 88 complete
# || resid || = 1.204e-02
# Cost :        1.418e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 89 complete
# || resid || = 1.204e-02
# Cost :        1.410e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 90 complete
# || resid || = 1.193e-02
# Cost :        1.402e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 91 complete
# || resid || = 1.190e-02
# Cost :        1.394e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 92 complete
# || resid || = 1.194e-02
# Cost :        1.387e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 93 complete
# || resid || = 1.194e-02
# Cost :        1.379e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 94 complete
# || resid || = 1.185e-02
# Cost :        1.371e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 95 complete
# || resid || = 1.181e-02
# Cost :        1.364e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 96 complete
# || resid || = 1.178e-02
# Cost :        1.357e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 97 complete
# || resid || = 1.178e-02
# Cost :        1.350e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 98 complete
# || resid || = 1.174e-02
# Cost :        1.342e+02
# =============================
#
# Entering inner loop for factor 0
# Entering inner loop for factor 1
# Entering inner loop for factor 2
# Entering inner loop for factor 3
# Entering inner loop for factor 4
#
# =============================
# Iteration 99 complete
# || resid || = 1.172e-02
# Cost :        1.335e+02
# =============================
#
#
# finished in 100 iterations
# convergence criterion: 5.219e-03
# || resid || = 1.172e-02
# Cost :        1.335e+02

# %%
def print_factor_norms(U):
    print("fro:   " + str([np.linalg.norm(Ui,'fro')**2 for Ui in U]))
    print("2-inf: " + str([np.max(np.linalg.norm(Ui, axis=1)) for Ui in U]))

print_factor_norms(kr_balance_factors(U))
# Out:
# fro:   [72.05857993436076, 72.05857993436074, 72.05857993436074, 72.05857993436074, 72.05857993436074]
# 2-inf: [2.033328352496376, 2.3142254893715326, 2.2564541391329627, 2.1653250268849966, 2.4672647373010657]

# %%
12**4
# Out:
# 20736

# %%
#Uinit = kr_rescale(Unew1, np.sqrt(np.product(data.shape) * data.sum() ** 2 / data.nnz), 'hs')
Uinit = kr_balance_factors(Unew1)

# %%
[np.linalg.norm(Ui, axis=1) for Ui in Uinit]
# Out:
# [array([ 2.08001386, 10.42777429, 10.1128947 ,  6.6132633 ,  9.45531551,
#          5.9790147 ,  6.17301208,  5.61011926,  6.92748812,  7.91455018,
#          9.05170632,  3.59023453,  8.91493848,  5.41256048,  8.46441992,
#          6.69298309,  3.72515018,  7.87567066,  5.14985328,  6.72473456,
#          8.41497874,  6.22426099,  7.61522846,  7.18548288,  6.25917487,
#          5.98368665,  6.68422246,  8.2805136 ,  7.61419683,  6.68607798]),
#  array([ 6.80192567,  4.94180072, 10.65764722,  9.37527578,  4.1640731 ,
#          8.2632507 ,  5.26218436,  5.33482722,  4.74283348,  4.25206187,
#          8.98392045,  6.64550901,  2.75182658,  8.95302777,  4.22325706,
#          5.12087387, 10.65269985,  3.47135731,  6.93166176,  6.64640223,
#          2.45658673,  6.07232662,  3.58223148,  7.00427952, 11.14947695,
#          5.54265843,  6.55008167,  7.85637575, 10.78953605, 11.50635994]),
#  array([8.41030716, 7.74812845, 7.74157753, 7.11456036, 7.68894355,
#         6.23591252, 9.33650178, 6.4839767 , 7.19762672, 5.46800957,
#         8.06926583, 7.37960555, 3.89145418, 4.22323405, 5.68746781,
#         9.44949768, 5.9890079 , 5.77546835, 9.07064067, 7.94387196,
#         7.96002538, 8.0968607 , 5.59566451, 9.38355385, 4.33782674,
#         3.65825547, 9.32394996, 7.70487665, 6.37659882, 5.97638675]),
#  array([7.37449919, 6.7807012 , 6.8104286 , 8.32844718, 5.69997958,
#         5.64708011, 6.12565956, 6.72579101, 5.64455537, 5.25177858,
#         8.19154923, 9.09143712, 5.28089581, 8.72037591, 7.02421792,
#         7.11561061, 7.34334752, 7.7682875 , 5.13367352, 7.28170147,
#         7.84185076, 7.96064383, 6.13111341, 4.71473514, 6.62327248,
#         9.21920552, 7.24629447, 7.155728  , 8.33287407, 9.24690508]),
#  array([ 4.14061594,  8.46161613,  9.25749802,  3.22841873,  8.51501485,
#          6.23543343,  8.55494838,  1.62059022,  7.03110579,  7.23337367,
#          7.78998848,  6.97139346,  7.8927785 ,  3.5033951 ,  5.12300621,
#          8.02377625,  7.87756154,  7.63704027, 10.39424153,  7.40353253,
#          7.59492447,  9.79944894,  4.80958995,  7.78221141,  7.36617628,
#          7.37615136,  4.94377966,  5.94059728,  6.88341435,  7.58105081])]

# %%
# %autoreload
Unew2, cost_arr = tensor_completion_maxnorm(data, 4 * r**t, 0.1 * np.sqrt(data.nnz), epsilon=1e-2,
                                            #sgd=True, sgd_batch_size=2000,
                                            U0 = kr_balance_factors(Unew1),
                                            init='svdrand',
                                            kappa=100, beta=1, 
                                            tol=1e-10, inner_tol=1e-12, max_iter=100, inner_max_iter=10, 
                                            verbosity=2, inner_line_iter=40,
                                            rebalance=True)
# Out:
# Initial cost: 1.090e+05
# Initial qnorm_ub: 1.090e+05
# || r || = 1.172e-02, delta = 1.000e-01
# Entering inner loop for factor 0
# qnorm_factr = 1.045e+04
# Entering inner loop for factor 1
# qnorm_factr = 6.434e+03
# Entering inner loop for factor 2
# qnorm_factr = 6.517e+03
# Entering inner loop for factor 3
# qnorm_factr = 5.977e+03
# Entering inner loop for factor 4
# qnorm_factr = 4.083e+03
#
# =============================
# Iteration 0 complete
#
#
# scaled || r || = 1.102e-01, delta = 1.000e-01
# Max-qnorm upper bound: 3.490e+04
# Cost function:         3.533e+04
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.588e+03
# Entering inner loop for factor 1
# qnorm_factr = 3.256e+03
# Entering inner loop for factor 2
# qnorm_factr = 3.449e+03
# Entering inner loop for factor 3
# qnorm_factr = 3.458e+03
# Entering inner loop for factor 4
# qnorm_factr = 2.847e+03
#
# =============================
# Iteration 1 complete
#
#
# scaled || r || = 1.055e-01, delta = 1.000e-01
# Max-qnorm upper bound: 2.007e+04
# Cost function:         2.035e+04
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 2.920e+03
# Entering inner loop for factor 1
# qnorm_factr = 2.101e+03
# Entering inner loop for factor 2
# qnorm_factr = 2.239e+03
# Entering inner loop for factor 3
# qnorm_factr = 2.460e+03
# Entering inner loop for factor 4
# qnorm_factr = 2.061e+03
#
# =============================
# Iteration 2 complete
#
#
# scaled || r || = 1.046e-01, delta = 1.000e-01
# Max-qnorm upper bound: 1.326e+04
# Cost function:         1.352e+04
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 2.104e+03
# Entering inner loop for factor 1
# qnorm_factr = 1.592e+03
# Entering inner loop for factor 2
# qnorm_factr = 1.664e+03
# Entering inner loop for factor 3
# qnorm_factr = 1.929e+03
# Entering inner loop for factor 4
# qnorm_factr = 1.661e+03
#
# =============================
# Iteration 3 complete
#
#
# scaled || r || = 1.036e-01, delta = 1.000e-01
# Max-qnorm upper bound: 9.838e+03
# Cost function:         1.008e+04
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.655e+03
# Entering inner loop for factor 1
# qnorm_factr = 1.276e+03
# Entering inner loop for factor 2
# qnorm_factr = 1.235e+03
# Entering inner loop for factor 3
# qnorm_factr = 1.492e+03
# Entering inner loop for factor 4
# qnorm_factr = 1.182e+03
#
# =============================
# Iteration 4 complete
#
#
# scaled || r || = 1.021e-01, delta = 1.000e-01
# Max-qnorm upper bound: 6.741e+03
# Cost function:         6.967e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.186e+03
# Entering inner loop for factor 1
# qnorm_factr = 9.850e+02
# Entering inner loop for factor 2
# qnorm_factr = 8.892e+02
# Entering inner loop for factor 3
# qnorm_factr = 1.249e+03
# Entering inner loop for factor 4
# qnorm_factr = 8.731e+02
#
# =============================
# Iteration 5 complete
#
#
# scaled || r || = 1.015e-01, delta = 1.000e-01
# Max-qnorm upper bound: 4.694e+03
# Cost function:         4.913e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 8.539e+02
# Entering inner loop for factor 1
# qnorm_factr = 7.458e+02
# Entering inner loop for factor 2
# qnorm_factr = 6.543e+02
# Entering inner loop for factor 3
# qnorm_factr = 1.031e+03
# Entering inner loop for factor 4
# qnorm_factr = 6.577e+02
#
# =============================
# Iteration 6 complete
#
#
# scaled || r || = 9.093e-02, delta = 1.000e-01
# Max-qnorm upper bound: 3.190e+03
# Cost function:         3.367e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.043e+02
# Entering inner loop for factor 1
# qnorm_factr = 4.959e+02
# Entering inner loop for factor 2
# qnorm_factr = 4.082e+02
# Entering inner loop for factor 3
# qnorm_factr = 7.262e+02
# Entering inner loop for factor 4
# qnorm_factr = 4.619e+02
#
# =============================
# Iteration 7 complete
#
#
# scaled || r || = 7.484e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.093e+03
# Cost function:         2.217e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.409e+02
# Entering inner loop for factor 1
# qnorm_factr = 3.780e+02
# Entering inner loop for factor 2
# qnorm_factr = 2.977e+02
# Entering inner loop for factor 3
# qnorm_factr = 5.765e+02
# Entering inner loop for factor 4
# qnorm_factr = 3.578e+02
#
# =============================
# Iteration 8 complete
#
#
# scaled || r || = 6.320e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.537e+03
# Cost function:         1.628e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 3.467e+02
# Entering inner loop for factor 1
# qnorm_factr = 3.020e+02
# Entering inner loop for factor 2
# qnorm_factr = 2.300e+02
# Entering inner loop for factor 3
# qnorm_factr = 4.804e+02
# Entering inner loop for factor 4
# qnorm_factr = 2.927e+02
#
# =============================
# Iteration 9 complete
#
#
# scaled || r || = 5.383e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.207e+03
# Cost function:         1.276e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 2.884e+02
# Entering inner loop for factor 1
# qnorm_factr = 2.533e+02
# Entering inner loop for factor 2
# qnorm_factr = 1.879e+02
# Entering inner loop for factor 3
# qnorm_factr = 4.159e+02
# Entering inner loop for factor 4
# qnorm_factr = 2.482e+02
#
# =============================
# Iteration 10 complete
#
#
# scaled || r || = 4.669e-02, delta = 1.000e-01
# Max-qnorm upper bound: 9.882e+02
# Cost function:         1.043e+03
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 2.473e+02
# Entering inner loop for factor 1
# qnorm_factr = 2.186e+02
# Entering inner loop for factor 2
# qnorm_factr = 1.588e+02
# Entering inner loop for factor 3
# qnorm_factr = 3.695e+02
# Entering inner loop for factor 4
# qnorm_factr = 2.171e+02
#
# =============================
# Iteration 11 complete
#
#
# scaled || r || = 4.107e-02, delta = 1.000e-01
# Max-qnorm upper bound: 8.383e+02
# Cost function:         8.829e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 2.178e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.922e+02
# Entering inner loop for factor 2
# qnorm_factr = 1.372e+02
# Entering inner loop for factor 3
# qnorm_factr = 3.328e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.930e+02
#
# =============================
# Iteration 12 complete
#
#
# scaled || r || = 3.686e-02, delta = 1.000e-01
# Max-qnorm upper bound: 7.249e+02
# Cost function:         7.626e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.951e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.721e+02
# Entering inner loop for factor 2
# qnorm_factr = 1.210e+02
# Entering inner loop for factor 3
# qnorm_factr = 3.040e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.748e+02
#
# =============================
# Iteration 13 complete
#
#
# scaled || r || = 3.360e-02, delta = 1.000e-01
# Max-qnorm upper bound: 6.399e+02
# Cost function:         6.728e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.775e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.555e+02
# Entering inner loop for factor 2
# qnorm_factr = 1.078e+02
# Entering inner loop for factor 3
# qnorm_factr = 2.789e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.593e+02
#
# =============================
# Iteration 14 complete
#
#
# scaled || r || = 3.119e-02, delta = 1.000e-01
# Max-qnorm upper bound: 5.688e+02
# Cost function:         5.983e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.627e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.417e+02
# Entering inner loop for factor 2
# qnorm_factr = 9.697e+01
# Entering inner loop for factor 3
# qnorm_factr = 2.571e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.465e+02
#
# =============================
# Iteration 15 complete
#
#
# scaled || r || = 2.939e-02, delta = 1.000e-01
# Max-qnorm upper bound: 5.112e+02
# Cost function:         5.383e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.504e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.302e+02
# Entering inner loop for factor 2
# qnorm_factr = 8.790e+01
# Entering inner loop for factor 3
# qnorm_factr = 2.381e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.356e+02
#
# =============================
# Iteration 16 complete
#
#
# scaled || r || = 2.804e-02, delta = 1.000e-01
# Max-qnorm upper bound: 4.633e+02
# Cost function:         4.885e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.400e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.218e+02
# Entering inner loop for factor 2
# qnorm_factr = 8.106e+01
# Entering inner loop for factor 3
# qnorm_factr = 2.236e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.275e+02
#
# =============================
# Iteration 17 complete
#
#
# scaled || r || = 2.695e-02, delta = 1.000e-01
# Max-qnorm upper bound: 4.273e+02
# Cost function:         4.512e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.313e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.137e+02
# Entering inner loop for factor 2
# qnorm_factr = 7.488e+01
# Entering inner loop for factor 3
# qnorm_factr = 2.094e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.196e+02
#
# =============================
# Iteration 18 complete
#
#
# scaled || r || = 2.623e-02, delta = 1.000e-01
# Max-qnorm upper bound: 3.937e+02
# Cost function:         4.166e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.239e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.071e+02
# Entering inner loop for factor 2
# qnorm_factr = 7.022e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.989e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.139e+02
#
# =============================
# Iteration 19 complete
#
#
# scaled || r || = 2.549e-02, delta = 1.000e-01
# Max-qnorm upper bound: 3.690e+02
# Cost function:         3.909e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.183e+02
# Entering inner loop for factor 1
# qnorm_factr = 1.014e+02
# Entering inner loop for factor 2
# qnorm_factr = 6.586e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.883e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.081e+02
#
# =============================
# Iteration 20 complete
#
#
# scaled || r || = 2.498e-02, delta = 1.000e-01
# Max-qnorm upper bound: 3.445e+02
# Cost function:         3.658e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.125e+02
# Entering inner loop for factor 1
# qnorm_factr = 9.618e+01
# Entering inner loop for factor 2
# qnorm_factr = 6.192e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.786e+02
# Entering inner loop for factor 4
# qnorm_factr = 1.030e+02
#
# =============================
# Iteration 21 complete
#
#
# scaled || r || = 2.460e-02, delta = 1.000e-01
# Max-qnorm upper bound: 3.237e+02
# Cost function:         3.444e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.075e+02
# Entering inner loop for factor 1
# qnorm_factr = 9.173e+01
# Entering inner loop for factor 2
# qnorm_factr = 5.850e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.701e+02
# Entering inner loop for factor 4
# qnorm_factr = 9.873e+01
#
# =============================
# Iteration 22 complete
#
#
# scaled || r || = 2.374e-02, delta = 1.000e-01
# Max-qnorm upper bound: 3.062e+02
# Cost function:         3.259e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.034e+02
# Entering inner loop for factor 1
# qnorm_factr = 8.807e+01
# Entering inner loop for factor 2
# qnorm_factr = 5.599e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.634e+02
# Entering inner loop for factor 4
# qnorm_factr = 9.535e+01
#
# =============================
# Iteration 23 complete
#
#
# scaled || r || = 2.303e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.922e+02
# Cost function:         3.112e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 1.002e+02
# Entering inner loop for factor 1
# qnorm_factr = 8.473e+01
# Entering inner loop for factor 2
# qnorm_factr = 5.331e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.561e+02
# Entering inner loop for factor 4
# qnorm_factr = 9.155e+01
#
# =============================
# Iteration 24 complete
#
#
# scaled || r || = 2.241e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.772e+02
# Cost function:         2.955e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 9.655e+01
# Entering inner loop for factor 1
# qnorm_factr = 8.162e+01
# Entering inner loop for factor 2
# qnorm_factr = 5.084e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.493e+02
# Entering inner loop for factor 4
# qnorm_factr = 8.806e+01
#
# =============================
# Iteration 25 complete
#
#
# scaled || r || = 2.189e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.637e+02
# Cost function:         2.814e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 9.321e+01
# Entering inner loop for factor 1
# qnorm_factr = 7.880e+01
# Entering inner loop for factor 2
# qnorm_factr = 4.872e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.435e+02
# Entering inner loop for factor 4
# qnorm_factr = 8.503e+01
#
# =============================
# Iteration 26 complete
#
#
# scaled || r || = 2.146e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.522e+02
# Cost function:         2.694e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 9.035e+01
# Entering inner loop for factor 1
# qnorm_factr = 7.625e+01
# Entering inner loop for factor 2
# qnorm_factr = 4.684e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.383e+02
# Entering inner loop for factor 4
# qnorm_factr = 8.230e+01
#
# =============================
# Iteration 27 complete
#
#
# scaled || r || = 2.114e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.417e+02
# Cost function:         2.586e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 8.777e+01
# Entering inner loop for factor 1
# qnorm_factr = 7.387e+01
# Entering inner loop for factor 2
# qnorm_factr = 4.510e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.335e+02
# Entering inner loop for factor 4
# qnorm_factr = 7.977e+01
#
# =============================
# Iteration 28 complete
#
#
# scaled || r || = 2.087e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.326e+02
# Cost function:         2.491e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 8.552e+01
# Entering inner loop for factor 1
# qnorm_factr = 7.179e+01
# Entering inner loop for factor 2
# qnorm_factr = 4.358e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.293e+02
# Entering inner loop for factor 4
# qnorm_factr = 7.741e+01
#
# =============================
# Iteration 29 complete
#
#
# scaled || r || = 2.073e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.241e+02
# Cost function:         2.405e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 8.344e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.990e+01
# Entering inner loop for factor 2
# qnorm_factr = 4.217e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.254e+02
# Entering inner loop for factor 4
# qnorm_factr = 7.523e+01
#
# =============================
# Iteration 30 complete
#
#
# scaled || r || = 2.063e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.166e+02
# Cost function:         2.328e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 8.158e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.821e+01
# Entering inner loop for factor 2
# qnorm_factr = 4.091e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.219e+02
# Entering inner loop for factor 4
# qnorm_factr = 7.318e+01
#
# =============================
# Iteration 31 complete
#
#
# scaled || r || = 2.061e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.097e+02
# Cost function:         2.258e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.985e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.664e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.975e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.187e+02
# Entering inner loop for factor 4
# qnorm_factr = 7.126e+01
#
# =============================
# Iteration 32 complete
#
#
# scaled || r || = 2.058e-02, delta = 1.000e-01
# Max-qnorm upper bound: 2.035e+02
# Cost function:         2.194e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.828e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.524e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.869e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.158e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.944e+01
#
# =============================
# Iteration 33 complete
#
#
# scaled || r || = 2.056e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.977e+02
# Cost function:         2.135e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.683e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.394e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.772e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.130e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.773e+01
#
# =============================
# Iteration 34 complete
#
#
# scaled || r || = 2.050e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.923e+02
# Cost function:         2.081e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.549e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.274e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.682e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.105e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.611e+01
#
# =============================
# Iteration 35 complete
#
#
# scaled || r || = 2.046e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.873e+02
# Cost function:         2.030e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.422e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.162e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.598e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.082e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.458e+01
#
# =============================
# Iteration 36 complete
#
#
# scaled || r || = 2.037e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.827e+02
# Cost function:         1.982e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.304e+01
# Entering inner loop for factor 1
# qnorm_factr = 6.058e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.519e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.060e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.312e+01
#
# =============================
# Iteration 37 complete
#
#
# scaled || r || = 2.026e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.783e+02
# Cost function:         1.937e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.191e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.961e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.446e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.039e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.175e+01
#
# =============================
# Iteration 38 complete
#
#
# scaled || r || = 2.014e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.742e+02
# Cost function:         1.894e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 7.085e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.869e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.377e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.020e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.044e+01
#
# =============================
# Iteration 39 complete
#
#
# scaled || r || = 2.001e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.704e+02
# Cost function:         1.854e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.984e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.783e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.312e+01
# Entering inner loop for factor 3
# qnorm_factr = 1.002e+02
# Entering inner loop for factor 4
# qnorm_factr = 5.921e+01
#
# =============================
# Iteration 40 complete
#
#
# scaled || r || = 1.987e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.667e+02
# Cost function:         1.816e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.888e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.701e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.251e+01
# Entering inner loop for factor 3
# qnorm_factr = 9.843e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.803e+01
#
# =============================
# Iteration 41 complete
#
#
# scaled || r || = 1.971e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.633e+02
# Cost function:         1.780e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.796e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.625e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.193e+01
# Entering inner loop for factor 3
# qnorm_factr = 9.680e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.691e+01
#
# =============================
# Iteration 42 complete
#
#
# scaled || r || = 1.956e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.601e+02
# Cost function:         1.746e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.708e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.552e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.139e+01
# Entering inner loop for factor 3
# qnorm_factr = 9.526e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.586e+01
#
# =============================
# Iteration 43 complete
#
#
# scaled || r || = 1.940e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.570e+02
# Cost function:         1.714e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.624e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.480e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.093e+01
# Entering inner loop for factor 3
# qnorm_factr = 9.397e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.494e+01
#
# =============================
# Iteration 44 complete
#
#
# scaled || r || = 1.924e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.544e+02
# Cost function:         1.686e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.558e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.415e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.038e+01
# Entering inner loop for factor 3
# qnorm_factr = 9.242e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.388e+01
#
# =============================
# Iteration 45 complete
#
#
# scaled || r || = 1.907e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.514e+02
# Cost function:         1.654e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.468e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.351e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.989e+01
# Entering inner loop for factor 3
# qnorm_factr = 9.102e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.291e+01
#
# =============================
# Iteration 46 complete
#
#
# scaled || r || = 1.891e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.486e+02
# Cost function:         1.625e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.389e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.290e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.945e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.976e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.203e+01
#
# =============================
# Iteration 47 complete
#
#
# scaled || r || = 1.876e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.461e+02
# Cost function:         1.599e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.318e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.233e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.902e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.856e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.119e+01
#
# =============================
# Iteration 48 complete
#
#
# scaled || r || = 1.861e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.437e+02
# Cost function:         1.573e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.249e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.178e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.869e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.762e+01
# Entering inner loop for factor 4
# qnorm_factr = 5.051e+01
#
# =============================
# Iteration 49 complete
#
#
# scaled || r || = 1.849e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.418e+02
# Cost function:         1.553e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.195e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.128e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.828e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.649e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.971e+01
#
# =============================
# Iteration 50 complete
#
#
# scaled || r || = 1.837e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.395e+02
# Cost function:         1.529e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.126e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.080e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.793e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.550e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.901e+01
#
# =============================
# Iteration 51 complete
#
#
# scaled || r || = 1.825e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.375e+02
# Cost function:         1.508e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.064e+01
# Entering inner loop for factor 1
# qnorm_factr = 5.034e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.758e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.453e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.832e+01
#
# =============================
# Iteration 52 complete
#
#
# scaled || r || = 1.815e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.356e+02
# Cost function:         1.487e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 6.003e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.993e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.728e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.368e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.770e+01
#
# =============================
# Iteration 53 complete
#
#
# scaled || r || = 1.805e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.338e+02
# Cost function:         1.469e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.946e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.953e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.697e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.285e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.710e+01
#
# =============================
# Iteration 54 complete
#
#
# scaled || r || = 1.797e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.321e+02
# Cost function:         1.451e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.888e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.915e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.670e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.209e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.654e+01
#
# =============================
# Iteration 55 complete
#
#
# scaled || r || = 1.789e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.305e+02
# Cost function:         1.435e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.835e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.879e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.643e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.135e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.599e+01
#
# =============================
# Iteration 56 complete
#
#
# scaled || r || = 1.783e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.290e+02
# Cost function:         1.418e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.782e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.845e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.623e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.081e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.556e+01
#
# =============================
# Iteration 57 complete
#
#
# scaled || r || = 1.778e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.278e+02
# Cost function:         1.406e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.741e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.813e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.598e+01
# Entering inner loop for factor 3
# qnorm_factr = 8.015e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.507e+01
#
# =============================
# Iteration 58 complete
#
#
# scaled || r || = 1.773e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.264e+02
# Cost function:         1.391e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.691e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.783e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.576e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.954e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.461e+01
#
# =============================
# Iteration 59 complete
#
#
# scaled || r || = 1.769e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.251e+02
# Cost function:         1.378e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.643e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.754e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.554e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.896e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.416e+01
#
# =============================
# Iteration 60 complete
#
#
# scaled || r || = 1.765e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.239e+02
# Cost function:         1.365e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.596e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.726e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.534e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.842e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.375e+01
#
# =============================
# Iteration 61 complete
#
#
# scaled || r || = 1.761e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.227e+02
# Cost function:         1.353e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.552e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.699e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.516e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.794e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.336e+01
#
# =============================
# Iteration 62 complete
#
#
# scaled || r || = 1.758e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.216e+02
# Cost function:         1.341e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.511e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.674e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.497e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.746e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.298e+01
#
# =============================
# Iteration 63 complete
#
#
# scaled || r || = 1.756e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.205e+02
# Cost function:         1.330e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.469e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.649e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.480e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.701e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.262e+01
#
# =============================
# Iteration 64 complete
#
#
# scaled || r || = 1.754e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.195e+02
# Cost function:         1.320e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.429e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.625e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.464e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.658e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.227e+01
#
# =============================
# Iteration 65 complete
#
#
# scaled || r || = 1.752e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.185e+02
# Cost function:         1.310e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.390e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.601e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.448e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.618e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.194e+01
#
# =============================
# Iteration 66 complete
#
#
# scaled || r || = 1.751e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.176e+02
# Cost function:         1.300e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.352e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.579e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.433e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.580e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.163e+01
#
# =============================
# Iteration 67 complete
#
#
# scaled || r || = 1.749e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.167e+02
# Cost function:         1.291e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.316e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.557e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.420e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.545e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.133e+01
#
# =============================
# Iteration 68 complete
#
#
# scaled || r || = 1.748e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.159e+02
# Cost function:         1.283e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.282e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.536e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.407e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.512e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.104e+01
#
# =============================
# Iteration 69 complete
#
#
# scaled || r || = 1.746e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.151e+02
# Cost function:         1.274e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.249e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.516e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.394e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.482e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.077e+01
#
# =============================
# Iteration 70 complete
#
#
# scaled || r || = 1.744e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.144e+02
# Cost function:         1.267e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.217e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.497e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.383e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.453e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.051e+01
#
# =============================
# Iteration 71 complete
#
#
# scaled || r || = 1.742e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.136e+02
# Cost function:         1.259e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.187e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.477e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.372e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.426e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.026e+01
#
# =============================
# Iteration 72 complete
#
#
# scaled || r || = 1.741e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.129e+02
# Cost function:         1.252e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.157e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.459e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.361e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.401e+01
# Entering inner loop for factor 4
# qnorm_factr = 4.002e+01
#
# =============================
# Iteration 73 complete
#
#
# scaled || r || = 1.739e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.123e+02
# Cost function:         1.245e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.129e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.440e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.351e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.378e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.979e+01
#
# =============================
# Iteration 74 complete
#
#
# scaled || r || = 1.738e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.117e+02
# Cost function:         1.239e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.101e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.422e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.342e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.355e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.957e+01
#
# =============================
# Iteration 75 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.110e+02
# Cost function:         1.232e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.075e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.404e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.333e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.334e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.936e+01
#
# =============================
# Iteration 76 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.105e+02
# Cost function:         1.226e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.049e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.387e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.324e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.315e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.916e+01
#
# =============================
# Iteration 77 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.099e+02
# Cost function:         1.220e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.025e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.369e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.316e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.296e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.896e+01
#
# =============================
# Iteration 78 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.093e+02
# Cost function:         1.215e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 5.000e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.352e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.308e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.278e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.877e+01
#
# =============================
# Iteration 79 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.088e+02
# Cost function:         1.209e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.977e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.335e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.300e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.261e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.858e+01
#
# =============================
# Iteration 80 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.083e+02
# Cost function:         1.204e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.954e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.318e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.293e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.244e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.840e+01
#
# =============================
# Iteration 81 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.078e+02
# Cost function:         1.199e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.932e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.302e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.286e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.228e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.823e+01
#
# =============================
# Iteration 82 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.073e+02
# Cost function:         1.194e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.910e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.285e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.279e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.213e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.806e+01
#
# =============================
# Iteration 83 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.068e+02
# Cost function:         1.189e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.889e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.269e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.272e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.199e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.789e+01
#
# =============================
# Iteration 84 complete
#
#
# scaled || r || = 1.737e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.064e+02
# Cost function:         1.184e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.868e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.253e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.265e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.185e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.773e+01
#
# =============================
# Iteration 85 complete
#
#
# scaled || r || = 1.736e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.059e+02
# Cost function:         1.180e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.847e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.237e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.259e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.171e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.757e+01
#
# =============================
# Iteration 86 complete
#
#
# scaled || r || = 1.736e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.055e+02
# Cost function:         1.175e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.827e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.222e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.253e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.158e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.741e+01
#
# =============================
# Iteration 87 complete
#
#
# scaled || r || = 1.735e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.050e+02
# Cost function:         1.171e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.807e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.206e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.247e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.145e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.726e+01
#
# =============================
# Iteration 88 complete
#
#
# scaled || r || = 1.734e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.046e+02
# Cost function:         1.166e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.788e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.191e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.241e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.133e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.711e+01
#
# =============================
# Iteration 89 complete
#
#
# scaled || r || = 1.733e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.042e+02
# Cost function:         1.162e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.769e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.176e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.235e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.121e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.696e+01
#
# =============================
# Iteration 90 complete
#
#
# scaled || r || = 1.731e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.038e+02
# Cost function:         1.158e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.751e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.161e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.229e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.109e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.682e+01
#
# =============================
# Iteration 91 complete
#
#
# scaled || r || = 1.730e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.034e+02
# Cost function:         1.153e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.732e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.146e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.224e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.098e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.668e+01
#
# =============================
# Iteration 92 complete
#
#
# scaled || r || = 1.728e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.030e+02
# Cost function:         1.149e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.714e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.131e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.218e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.086e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.654e+01
#
# =============================
# Iteration 93 complete
#
#
# scaled || r || = 1.726e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.026e+02
# Cost function:         1.145e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.696e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.116e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.213e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.075e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.641e+01
#
# =============================
# Iteration 94 complete
#
#
# scaled || r || = 1.722e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.022e+02
# Cost function:         1.141e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.680e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.103e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.208e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.061e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.627e+01
#
# =============================
# Iteration 95 complete
#
#
# scaled || r || = 1.717e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.018e+02
# Cost function:         1.137e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.662e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.088e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.203e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.047e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.614e+01
#
# =============================
# Iteration 96 complete
#
#
# scaled || r || = 1.713e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.014e+02
# Cost function:         1.132e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.644e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.073e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.198e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.034e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.600e+01
#
# =============================
# Iteration 97 complete
#
#
# scaled || r || = 1.708e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.011e+02
# Cost function:         1.128e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.626e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.058e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.194e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.020e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.587e+01
#
# =============================
# Iteration 98 complete
#
#
# scaled || r || = 1.703e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.007e+02
# Cost function:         1.124e+02
#
# =============================
#
# Entering inner loop for factor 0
# qnorm_factr = 4.608e+01
# Entering inner loop for factor 1
# qnorm_factr = 4.043e+01
# Entering inner loop for factor 2
# qnorm_factr = 2.189e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.006e+01
# Entering inner loop for factor 4
# qnorm_factr = 3.573e+01
#
# =============================
# Iteration 99 complete
#
#
# scaled || r || = 1.699e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.003e+02
# Cost function:         1.119e+02
#
# =============================
#
#
# finished in 100 iterations
#
#
# scaled || r || = 1.699e-02, delta = 1.000e-01
# Max-qnorm upper bound: 1.003e+02
# Cost function:         1.119e+02

# %%
qnorm_max = max_qnorm_ub(Unew2)
print(qnorm_max)
# Out:
# 100.27215916387408

# %%
Unew1
# Out:
# [array([[-6.50869055e-04,  2.75510672e-01, -2.83243952e-08, ...,
#          -1.12622983e-01,  3.02720692e-01,  1.76849868e-03],
#         [-2.36183534e-02,  7.38293465e-03,  1.21928876e-09, ...,
#           3.35085741e-02,  5.25910437e-01, -9.12024926e-01],
#         [ 8.88714191e-04, -2.21940906e-02,  6.96609898e-09, ...,
#           4.47256634e-02,  1.17389110e-02, -1.86816957e-01],
#         ...,
#         [-7.48932018e-02, -4.52302939e-03, -1.04658767e-08, ...,
#          -7.85818565e-02, -6.91734438e-01,  9.40658850e-01],
#         [ 6.89906258e-04, -4.29596841e-02,  3.96071420e-10, ...,
#           9.28075065e-04,  7.58069922e-02, -1.64840626e-01],
#         [ 1.45380168e-03, -1.28044206e-02, -8.04543687e-10, ...,
#           1.29736055e-03,  6.77962968e-02, -1.53383157e-01]], dtype=float64),
#  array([[-2.59955609e-04, -2.80859734e-01, -1.22286280e-07, ...,
#           8.35554819e-02, -3.96465292e-02,  1.02663036e-01],
#         [-2.35485923e-02, -6.99465451e-03,  1.00405446e-07, ...,
#          -7.39880290e-02, -8.94065509e-01,  2.60527531e-01],
#         [-4.22254045e-02,  1.54835455e-04,  4.48217139e-08, ...,
#          -1.41210581e-02,  7.69185132e-02, -4.49686462e-01],
#         ...,
#         [-5.82474553e-04,  1.50787767e-05,  9.20167178e-08, ...,
#           5.86586730e-02, -2.64495368e-01,  5.31152645e-03],
#         [-2.03174512e-04,  9.43522807e-02, -3.51573890e-07, ...,
#          -7.70905931e-02, -8.69559256e-02,  7.41136709e-02],
#         [-4.17392156e-03,  1.42457009e-01, -7.69136972e-08, ...,
#          -2.83508612e-01,  3.19914862e-01,  6.36792110e-01]], dtype=float64),
#  array([[-0.00980652, -0.18647036,  0.10205961, ...,  0.49187537,
#           0.44428706, -0.06812227],
#         [ 0.63586028,  0.07658577, -0.00222407, ...,  0.33537671,
#           0.08082982, -0.20049133],
#         [-0.10251241,  0.00256653, -0.02116425, ..., -0.16286575,
#           0.35467229, -0.03433372],
#         ...,
#         [ 0.7616468 ,  0.01089188,  0.04304586, ..., -0.03489343,
#           0.05527955, -0.63237814],
#         [-0.01247028,  0.0284286 , -0.01113886, ...,  0.05605636,
#           0.02331178,  0.3429892 ],
#         [ 0.06739296,  0.05813861, -0.01490855, ..., -0.13764032,
#          -0.1289438 , -0.02464337]], dtype=float64),
#  array([[-0.00238909,  0.00582996, -0.01758313, ...,  0.11221298,
#           0.21021274,  0.06897728],
#         [-0.01698389, -0.00924553,  0.10669808, ...,  0.09357786,
#           0.0049981 , -0.07404972],
#         [ 0.01644064,  0.01073472, -0.0223871 , ..., -0.05834367,
#           0.15892433, -0.35178453],
#         ...,
#         [-0.10301679,  0.06057235, -0.06342057, ...,  0.0087481 ,
#          -0.01571368,  0.04550805],
#         [ 0.0426036 , -0.04124209,  0.01049381, ...,  0.05846902,
#          -0.52631688, -0.16411775],
#         [-0.01350445, -0.0603115 ,  0.01715018, ..., -0.28807138,
#           0.05316284,  0.07361128]], dtype=float64),
#  array([[ 0.06471547,  0.07408444, -0.01227664, ..., -0.02929347,
#           0.09706598, -0.02871553],
#         [-0.03012032,  0.01125938, -0.00055487, ..., -0.38518687,
#          -0.2046903 , -0.23837168],
#         [ 0.07345516, -0.1253679 ,  0.09529261, ..., -0.10075653,
#          -0.01995387,  0.02903523],
#         ...,
#         [-0.11877947, -0.00229052,  0.058214  , ...,  0.28865764,
#          -0.09392537, -0.08752905],
#         [ 0.03101995,  0.05960638,  0.01023002, ..., -0.34979247,
#           0.26677671,  0.23826116],
#         [ 0.00972448, -0.11705254, -0.01962947, ..., -0.20667379,
#          -0.18710206,  0.05997349]], dtype=float64)]

# %%
expander_eigs = np.abs(nx.linalg.adjacency_spectrum(expander))
expander_eigs.sort()
print(expander_eigs[-10:])
# Out:
# [2.71280726 2.77758858 2.83397153 2.98139489 3.33483919 3.71436113
#  3.72929617 4.02447456 4.02522023 6.        ]

# %%
bound = 2**(2*t-4) * 1.8**(t-1) * (qnorm_max + qnorm_true)**2 * ((1 + expander_eigs[-2]/expander_eigs[-1])**(t-1) - 1)
print(bound)
print(bound / n**t)
# Out:
# 113819966.07215978
# 4.683949221076534

# %%
#print("loss of U parafac:  %f" % np.sqrt(loss(U,data) / data.nnz))
print("loss of U true:     %.3e" % np.sqrt(loss(U, data) / data.nnz))
#print("loss of U alt-min:  %.3e" % np.sqrt(loss(Unew1, data) / data.nnz))
print("loss of U max:      %.3e" % np.sqrt(loss(Unew2, data) / data.nnz))
# Out:
# loss of U true:     4.997e-03
# loss of U max:      1.699e-02

# %%
import matplotlib.pyplot as plt

plt.semilogy(cost_arr)
plt.xlabel('iterate')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %% [markdown]
# ## Generalization error

# %%
def gen_err(Upred, Utrue):
    norm_true = kr_dot(Utrue, Utrue)
    mse_gen = kr_dot(Upred, Upred) + norm_true - 2 * kr_dot(Upred, Utrue)
    return np.sqrt(mse_gen / norm_true)

def mse_gen_err(Upred, Utrue):
    norm_true = kr_dot(Utrue, Utrue)
    mse_gen = kr_dot(Upred, Upred) + norm_true - 2 * kr_dot(Upred, Utrue)
    return np.sqrt(mse_gen / Upred[0].shape[0] ** len(Upred))

print("relative RMSE max:      %1.4e" % gen_err(Unew2, U))
print("MSE max:                %1.4e" % mse_gen_err(Unew2, U))
# Out:
# relative RMSE max:      3.1463e-02
# MSE max:                3.1463e-02

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, axs = plt.subplots(1,t, figsize=(6, 20))
for i in range(t):
    im = axs[i].imshow(Unew2[i])
    divider = make_axes_locatable(axs[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
    if i > 0:
        axs[i].set_yticks([])

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, axs = plt.subplots(1,t, figsize=(6, 20))
for i in range(t):
    im = axs[i].imshow(U[i])
    divider = make_axes_locatable(axs[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im, cax=cax, orientation='vertical')
    if i > 0:
        axs[i].set_yticks([])
