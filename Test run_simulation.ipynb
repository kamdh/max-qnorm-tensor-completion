# %%
import numpy as np
from run_sweep_iid import *

# %%
n = 20
t = 4
r = 3
sigma = 0.1
r_fit = 40
const = 40

# %%
help(run_simulation)
# Out:
# Help on function run_simulation in module run_sweep_iid:
#
# run_simulation(n, t, r, sigma, r_fit, rep, const=10.0, max_iter=100, inner_max_iter=40, tol=1e-08, alg='max', verbosity=0, kappa=100, beta=1, epsilon=0.001, delta=None)

# %%
run_simulation(n, t, r, sigma, r_fit, 0, const, verbosity=2)

# %%
result = run_simulation(10, 5.0, 3.0, 0.01, 40, 2.0, 20.0, verbosity=2, max_iter=100, inner_max_iter=10, delta=0.01, tol=1e-10)
print(result)
# Out:
# Running a simulation: n = 10, t = 5, r = 3, sigma = 0.010000, r_fit = 40
#
# max_qnorm_ub_true = 8.545e+01
# number of samples = 3000, 3.00e+00%
# Initial cost: 1.027e+05
# Initial qnorm_ub: 3.247e+02
# || r || = 8.362e-01, delta = 1.000e-02
# Entering inner loop for factor 0
# qnorm_factr = 9.588e+01
# Entering inner loop for factor 1
# qnorm_factr = 2.126e+02
# Entering inner loop for factor 2
# qnorm_factr = 2.368e+02
# Entering inner loop for factor 3
# qnorm_factr = 3.135e+02
# Entering inner loop for factor 4
# qnorm_factr = 6.134e+02
#
# ...
# Iteration 0 complete
#
#
# scaled || r || = 4.695e-01, delta = 1.000e-02
# Max-qnorm upper bound: 2.956e+03
# Cost function:         3.463e+04
#
# ...
#
# Entering inner loop for factor 0
# qnorm_factr = 6.056e+02
# Entering inner loop for factor 1
# qnorm_factr = 7.209e+02
# Entering inner loop for factor 2
# qnorm_factr = 6.226e+02
# Entering inner loop for factor 3
# qnorm_factr = 4.834e+02
# Entering inner loop for factor 4
# ...

# %%
result
# Out:
# (0.009943923173810792,
#  157.30171973608552,
#  0.027180987384256165,
#  966.1218844150704,
#  0.1254275247745984)

# %%
3 * 5 *3 * np.log10(3) * 20

# %%
20**-2.

# %%
np.log(3)
