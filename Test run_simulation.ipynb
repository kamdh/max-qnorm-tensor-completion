# %%
import numpy as np
from run_sweep_expander import *

# %load_ext autoreload

# %%
n = 40
t = 3
r = 3
sigma = 0.001
r_fit = 20
#const = 12
d = 7

# %%
help(run_simulation)
# Out:
# Help on function run_simulation in module run_sweep_expander:
#
# run_simulation(n, t, r, sigma, r_fit, rep, d=10, max_iter=None, inner_max_iter=10, tol=1e-10, alg='max', verbosity=0, kappa=100, beta=1, epsilon=0.01, delta=None)

# %%
# %autoreload
result = run_simulation(n, t, r, 0., 2*r_fit, 2.0, d=9, verbosity=2, delta=0.05, kappa=100, beta=1)
print(result)
# Out:
# Running a simulation: n = 40, t = 3, r = 3, sigma = 0.000000, r_fit = 40
#
# max_qnorm_ub_true = 8.764e+00
# expander degree = 9, sampling 5.06e+00%
# Initial cost: 1.413e+05
# Initial qnorm_ub: 1.524e+00
# || r || = 9.840e-01, delta = 5.000e-02
# Entering inner loop for factor 0
# qnorm_factr = 1.339e+00
# Entering inner loop for factor 1
# qnorm_factr = 1.363e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.497e+01
#
# ...
# Iteration 0 complete
#
#
# scaled || r || = 4.679e-01, delta = 5.000e-02
# Max-qnorm upper bound: 4.595e+01
# Cost function:         2.834e+04
#
# ...
#
# Entering inner loop for factor 0
# qnorm_factr = 1.179e+01
# Entering inner loop for factor 1
# qnorm_factr = 1.457e+01
# Entering inner loop for factor 2
# qnorm_factr = 1.540e+01
#
# ...
# Iteration 1 complete
#
#
# scaled || r || = 1.680e-01, delta = 5.000e-02
# Max-qnorm upper bound: 5.172e+01
# Cost function:         2.315e+03
#
# ...
#
# Entering inner loop for factor 0
# qnorm_factr = 1.168e+01
# ...

# %%
result

# %%
3 * 5 *3 * np.log10(3) * 20

# %%
20**-2.

# %%
20**1.25

# %%
5/(5-1)
