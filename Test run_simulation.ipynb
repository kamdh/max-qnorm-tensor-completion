# %%
import numpy as np
from run_sweep_expander import *

# %load_ext autoreload

# %%
n = 1000
t = 4
r = 3
sigma = 0.0
r_fit = 32
#const = 12
d = 12

# %%
help(run_simulation)
# Out:
# Help on function run_simulation in module run_sweep_expander:
#
# run_simulation(n, t, r, sigma, r_fit, rep, d=10, max_iter=None, inner_max_iter=10, tol=1e-10, alg='fro', verbosity=0, kappa=100, beta=1, epsilon=0.01, delta=None)

# %%
(d/n)**(t-1)
# Out:
# 1.728e-06

# %%
# %autoreload
result = run_simulation(n, t, r, 0., r_fit, 4, d=d, verbosity=2, delta=0.05, kappa=100, beta=1, alg='fro', max_iter=271)
print(result)
# Out:
# Running a simulation: n = 1000, t = 4, r = 3, sigma = 0.000000, r_fit = 32, alg=fro
#
# max_qnorm_ub_true = 3.941e+01
# expander degree = 12, sampling 1.73e-04%
# Initial cost: 7.697e+07
# Initial qnorm_ub: 8.482e-01
# || r || = 9.938e-01, delta = 5.000e-02
# Entering inner loop for factor 0
# qnorm_factr = 1.062e+00
# Entering inner loop for factor 1
# qnorm_factr = 1.858e+00
# Entering inner loop for factor 2
# qnorm_factr = 6.283e+01
# Entering inner loop for factor 3
# qnorm_factr = 7.928e+01
#
# ...
# Iteration 0 complete
#
#
# scaled || r || = 9.928e-01, delta = 5.000e-02
# Max-qnorm upper bound: 3.093e+01
# Cost function:         7.680e+07
#
# ...
#
# Entering inner loop for factor 0
# qnorm_factr = 1.944e+01
# Entering inner loop for factor 1
# qnorm_factr = 3.252e+01
# Entering inner loop for factor 2
# qnorm_factr = 3.479e+01
# Entering inner loop for factor 3
# qnorm_factr = 6.667e+01
#
# ...
# Iteration 1 complete
#
#
# scaled || r || = 9.871e-01, delta = 5.000e-02
# ...

# %%
result
# Out:
# (0.0,
#  39.414819264217435,
#  0.001660774324614873,
#  49.168516501680054467,
#  0.015133934711390585)

# %%
3 * 5 *3 * np.log10(3) * 20

# %%
20**-2.

# %%
20**1.25

# %%
5/(5-1)
